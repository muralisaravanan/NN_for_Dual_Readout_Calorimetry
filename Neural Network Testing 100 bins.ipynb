# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.signal as signal
import random
import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import utils
import h5py
import time
from sklearn.preprocessing import MinMaxScaler

from numpy.random import seed
seed(5)
from tensorflow import set_random_seed
set_random_seed(7)
'''
Based on work by Federico De Guio: https://github.com/deguio/ML4DQM/blob/master/notebooks/Semi_Supervised/AE_ssl_random_hotdead_size.ipynb
See: https://indico.cern.ch/event/783825/contributions/3261553/attachments/1789464/2914642/hcaldpg_fpga_ml_reco_01feb2019.pdf
for possible implementation into FPGA
'''
# Out:
# Using TensorFlow backend.
# '\nBased on work by Federico De Guio: https://github.com/deguio/ML4DQM/blob/master/notebooks/Semi_Supervised/AE_ssl_random_hotdead_size.ipynb\nSee: https://indico.cern.ch/event/783825/contributions/3261553/attachments/1789464/2914642/hcaldpg_fpga_ml_reco_01feb2019.pdf\nfor possible implementation into FPGA\n'

# %%
def plot_loss(data, title,yscale="linear"):     
    """ Plots the training and validation loss yscale can be: linear,log,symlog """
    plt.figure()
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(title)
    plt.plot(data.history["loss"])#, linestyle=line_styles[0], color=color_palette["Indigo"][900], linewidth=3)
    plt.plot(data.history["val_loss"])#, linestyle=line_styles[2], color=color_palette["Teal"][300], linewidth=3)
    plt.legend(["Train", "Validation"])#, loc="upper right", frameon=False)
    plt.yscale(yscale)
    plt.show();

# %%
class Pulse:
    '''
    A class that generates a Pulse that includes both Cerenkov and Scintillation Pulse. The pulse is randomly generated 
    through the use of a probability density function that is generated by the given parameters.
    The pulse has 512 samples and is identifiable by 3 parameters:
        1) ratio: If ratio is positive, it is the ratio of the Area of Cernekov:Area of Scintillation. 
                  If ratio is negative, it is the ratio of the Area of Scintillation:Area of Cerenkov
                
        This is altered by changing the height of the Cerenkov pulse (Cerenkov Radiation).
        
        
        2) separation: Time between the two pulses
       
    '''
    
    
    
    def __init__(self, photoelectrons, ratio, scint_decay):
        self.start=10
        self.rise=0.05
        self.cerenkov_decay=2.5
        self.scint_decay=scint_decay
        
        self.end_time=250
        self.timestep=0.1
        self.t=t=np.arange(0,self.end_time,self.timestep)
        self.bin_number=100
        

        if ratio>0:
            self.ratio=ratio
        else:
            self.ratio=-(1/ratio)
            
        self.photoelectrons=photoelectrons
        self.cerenkov_strength=self.ratio
        #self.cerenkov_percent=self.ratio/(self.ratio+1)
        #self.scint_percent=1/(self.ratio+1)
        self.interp=self.interpolator()
        self.cerenkov_area=sp.integrate.quad(self.cerenkov_scaled, self.start, self.end_time)
        self.scint_area=sp.integrate.quad(self.scintillation_normalized, self.start, self.end_time)
        
        self.cerenkov_percent=(self.cerenkov_area[0])/(self.cerenkov_area[0]+self.scint_area[0])
        self.scint_percent=(self.scint_area[0])/(self.cerenkov_area[0]+self.scint_area[0])
 
    def cerenkov(self,t):
        return (1-np.exp(-((t-self.start)/self.rise)))*(np.exp(-((t-self.start)/self.cerenkov_decay)))

    def scintillation(self, t):
        return (1-np.exp(-((t-self.start)/self.rise)))*(np.exp(-((t-self.start)/self.scint_decay)))
    
    def cerenkov_scaled(self, t):
        cerenkov=self.cerenkov(t)
        norm=sp.integrate.quad(self.cerenkov, self.start, self.end_time)
        return (1/norm[0])*self.cerenkov_strength*cerenkov
    
    def scintillation_normalized(self, t):
        scint=self.scintillation(t)
        norm=sp.integrate.quad(self.scintillation, self.start, self.end_time)
        return (1/norm[0])*scint


    def pulse_func_helper(self, time):
        if time<self.start:
            return 0
        else:
            return self.cerenkov_scaled(time) + self.scintillation_normalized(time) 
    
    
    def pulse_func(self, t):
        pulse=[]
                        
        for time in t:
            pulse.append(self.pulse_func_helper(time))
        return np.asarray(pulse)


    def randomValues(self,number):
        val=[]
        for x in range(number):
            val.append(random.random())
        return val

    
    def graph_both_pulses(self):
        t=np.arange(self.start,self.end_time,self.timestep)
        plt.figure()
        plt.plot(t, self.cerenkov_scaled(t), c='r', label="cerenkov")
        plt.plot(t, self.scintillation_normalized(t), label='scintillation')
        plt.xlabel("Time (ns)")
        plt.title("Pulse with ratio "+ str(self.ratio)+ " and scint decay "+str(self.scint_decay))
        plt.legend()
    
    def final_pdf(self, t):
        radiation=self.pulse_func(t)
        norm=sp.integrate.quad(self.pulse_func_helper, 0, self.end_time)
        return (1/norm[0])*radiation
    
    def graph_pdf(self):
        plt.figure()
        plt.plot(self.t, self.final_pdf(self.t))
        plt.xlabel("Time (ns)")
        plt.title("Pulse with ratio "+ str(self.ratio)+ " and scint decay "+str(self.scint_decay))

    def final_cdf(self, t):
        prob=self.final_pdf(t)
        return np.cumsum(prob)*self.timestep
    
    def interpolator(self):
        cumul=self.final_cdf(self.t)
        hits=self.photoelectrons
        #print(hits)
        rand=self.randomValues(hits)
        #print(rand)
        interp=sp.interpolate.interp1d(cumul,self.t, fill_value="extrapolate")
        return interp
    
    def output(self):
        hits=self.photoelectrons
        #print(hits)
        rand=self.randomValues(hits)
        vals=self.interp(rand)
        hist, bin_edges=np.histogram(vals, bins=self.bin_number, range=(0,self.end_time))
        return hist, self.cerenkov_percent, self.scint_percent
    
    def output2(self):
        hits=self.photoelectrons
        #print(hits)
        rand=self.randomValues(hits)
        vals=self.interp(rand)
        hist, bin_edges=np.histogram(vals, bins=self.bin_number, range=(0,self.end_time))
        return hist, bin_edges, self.cerenkov_percent, self.scint_percent

    
    '''
    DEPRECAYED FUNCTIONS
    def final_distribution(self):
        cumul=self.final_cdf(self.t)
        hits=self.photoelectrons
        #print(hits)
        rand=self.randomValues(hits)
        #print(rand)
        interp=sp.interpolate.interp1d(cumul,self.t, fill_value="extrapolate")
        vals=interp(rand)
        #print(vals)
        return vals
        
    def histogram_generator(self):
        data=self.final_distribution()
        hist, bin_edges=np.histogram(data, bins=self.bin_number, range=(0,self.end_time))
        #print(bin_edges)
        return hist
    
    def output(self):
        
        
        return self.histogram_generator(), self.cerenkov_percent, self.scint_percent
    '''

# %%
class PulseLibrary:
    '''
    Creates a list of pulses with the attached ratio.
    labels has form of ratioXXXscint_decayXXeventXX
    '''
    
    def __init__(self, seed, name, eventsperexperiment, photoelectrons,ratios=[1],scint_decays=[50]):
        np.random.seed(seed)
        self.name=name +'.hdf5'
        self.scint_decays=scint_decays
        self.ratios=ratios
        self.photoelectrons=photoelectrons
        self.eventsperexperiment=eventsperexperiment
        self.labels=[]
        self.pulses=[]
        self.inputs=[]
        self.outputs=[]
        
        
        
        file=h5py.File(self.name, 'w')
        
        for ratio in self.ratios:
            for scint_decay in self.scint_decays:
                pulse=Pulse(self.photoelectrons, ratio, scint_decay)
                
                group_name="ratio"+str(ratio)+"scintdecay"+str(scint_decay)
                
                group = file.create_group(group_name)
                
                for i in range(eventsperexperiment):
                    
                    self.pulses.append(pulse)
                    ins, out1, out2=pulse.output()
                    outs=[out1, out2]
                    
                    
                    label="ratio"+str(ratio)+"scintdecay"+str(scint_decay)+"event"+str(i)
                    self.labels.append(label)
                    self.inputs.append(ins)
                    self.outputs.append(outs)
                    
                    subgroup=group.create_group(label)
                    
                    
                    d1 = subgroup.create_dataset(label+'input', data=ins)
                    d2 = subgroup.create_dataset(label+'output', data=outs)
                    
        
        file.close()
    
    def get_inputs(self):
        return np.asarray(self.inputs)
    
    def get_outputs(self):
        return np.asarray(self.outputs)
    
    def get_labels(self):
        return self.labels
    
    def get_pulses(self):
        return np.asarray(self.pulses)

# %%
integration_vals=[1.25, 3.75, 6.25, 8.75, 11.25, 13.75, 16.25, 18.75, 21.25, 23.75, 26.25, 28.75, 31.25, 33.75, 36.25, 38.75, 41.25, 43.75, 46.25, 48.75, 51.25, 53.75, 56.25, 58.75, 61.25, 63.75, 66.25, 68.75, 71.25, 73.75, 76.25, 78.75, 81.25, 83.75, 86.25, 88.75, 91.25, 93.75, 96.25, 98.75, 101.25, 103.75, 106.25, 108.75, 111.25, 113.75, 116.25, 118.75, 121.25, 123.75, 126.25, 128.75, 131.25, 133.75, 136.25, 138.75, 141.25, 143.75, 146.25, 148.75, 151.25, 153.75, 156.25, 158.75, 161.25, 163.75, 166.25, 168.75, 171.25, 173.75, 176.25, 178.75, 181.25, 183.75, 186.25, 188.75, 191.25, 193.75, 196.25, 198.75, 201.25, 203.75, 206.25, 208.75, 211.25, 213.75, 216.25, 218.75, 221.25, 223.75, 226.25, 228.75, 231.25, 233.75, 236.25, 238.75, 241.25, 243.75, 246.25, 248.75]

# %%
def model_creator():
    model = Sequential()
    #model.add(Dense(50,  input_shape=(300,), kernel_initializer='normal', activation='relu'))
    model.add(Dense(10, input_shape=(100,), kernel_initializer='ones', activation='relu'))
    model.add(Dense(2, kernel_initializer='ones', activation='relu'))
# Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

def model_trainer(pulse_library, model_name):
    model=model_creator()
    file=h5py.File(pulse_library, 'r')
    X=[]
    Y=[]
    for groups in file.values():
        for subgroup in groups.values():
            for event in subgroup.values():
                #if not "ratio0.0scint"in event.name:
                #if 'event0' in event.name:  
                if event.name[-5:]=="input":
                    data=event[:]
                    data=np.asarray(data)                      
                    X.append(data)
                    #X.append(data)
                elif event.name[-6:]=="output":
                    Y.append(event[:])
    file.close()    
    X=np.asarray(X)

    Y=np.asarray(Y)
    norm_factor=np.amax(X)
    X_scaled=X/norm_factor
    Xtrain, Xval, Ytrain, Yval = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)
    checkpointer = ModelCheckpoint(filepath=model_name+"weights.hdf5",verbose=3, save_best_only=True)
    earlystop= EarlyStopping(monitor='val_loss', min_delta=0, patience=50 ,verbose=1, mode='auto')
    history=model.fit(Xtrain,Ytrain,epochs=200,verbose=1
                             ,validation_data=(Xval,Yval)
                             ,shuffle=True, batch_size=16
                             ,callbacks=[earlystop,checkpointer])
    model.save(model_name)
    return model, history

def model_verifier(pulse_library, model_name, ratios, scint_decays, eventsperexperiment):
    model=load_model(model_name)
    file=h5py.File(pulse_library, 'r')
    X=[]
    Y=[]
    labels=[]
    
    for ratio in ratios:
        for scint_decay in scint_decays:
            tempX=[]
            tempY=[]
            templabels=[]
            for i in range(eventsperexperiment):
                label="/ratio"+str(ratio)+"scintdecay"+str(scint_decay)+"/ratio"+str(ratio)+"scintdecay"+str(scint_decay)+"event"+str(i)+"/ratio"+str(ratio)+"scintdecay"+str(scint_decay)+"event"+str(i)
                #print(label)
                Xdata=file[label+"input"][:]
                Ydata=file[label+"output"][:]
                Xdata=np.asarray(Xdata)
                
                tempX.append(Xdata)
                tempY.append(Ydata)
                templabels.append(label)
            X.append(tempX)
            Y.append(tempY)
            labels.append(templabels)
    
    file.close()
    X=np.asarray(X)
    Y=np.asarray(Y)
    results=[]
    norm_factor=np.amax(X)
    X_scaled=X/norm_factor
    
    for x in X_scaled:
        prediction=model.predict(x)
        results.append(prediction)

    results=np.array(results)
    #results=model.predict(X)
    return results, Y, labels
    
    
    '''
    deprecated
    for groups in file.values():
        tempX=[]
        tempY=[]
        templabels=[]
        for subgroup in groups.values():
            
            for event in subgroup.values():
                if event.name[-5:]=="input":
                    tempX.append(event)
                    templabels.append(event.name)
                elif event.name[-6:]=="output":
                    tempY.append(event)
        X.append(tempX)
        Y.append(tempY)
        labels.append(templabels)
            
    X=np.asarray(X)
    Y=np.asarray(Y)
    results=[]
    for x in X:
        prediction=model.predict(x)
        results.append(prediction)
    results=np.array(results)
    #results=model.predict(X)
    return results, Y, labels
    '''

# %% [markdown]
# # 10,000 photoelectrons

# %%
nn5_scint_decays=np.linspace(15,50,10)
nn5_ratios=np.linspace(-25,25,10)
nn5_eventsperexperiment=500
nn5_model,nn5_history=model_trainer('FinerParameterSpace500events10000photons100binsTrainingLibrary_20x20.hdf5', 'NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5')
plot_loss(data=nn5_history,title="Loss vs Epoch for nn5",yscale='linear')
# Out:
# Train on 160000 samples, validate on 40000 samples
# Epoch 1/200
# 160000/160000 [==============================] - 42s 260us/step - loss: 5.3024 - val_loss: 0.1583
#
# Epoch 00001: val_loss improved from inf to 0.15832, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 2/200
# 160000/160000 [==============================] - 38s 235us/step - loss: 0.0161 - val_loss: 7.0702e-05
#
# Epoch 00002: val_loss improved from 0.15832 to 0.00007, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 3/200
# 160000/160000 [==============================] - 38s 237us/step - loss: 7.5334e-05 - val_loss: 6.8184e-05
#
# Epoch 00003: val_loss improved from 0.00007 to 0.00007, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 4/200
# 160000/160000 [==============================] - 38s 236us/step - loss: 7.3753e-05 - val_loss: 6.8148e-05
#
# Epoch 00004: val_loss improved from 0.00007 to 0.00007, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 5/200
# 160000/160000 [==============================] - 33s 209us/step - loss: 7.2812e-05 - val_loss: 7.0751e-05
#
# Epoch 00005: val_loss did not improve from 0.00007
# Epoch 6/200
# 160000/160000 [==============================] - 32s 203us/step - loss: 7.2243e-05 - val_loss: 7.3092e-05
#
# Epoch 00006: val_loss did not improve from 0.00007
# Epoch 7/200
# 160000/160000 [==============================] - 33s 205us/step - loss: 7.1587e-05 - val_loss: 7.1300e-05
#
# Epoch 00007: val_loss did not improve from 0.00007
# Epoch 8/200
# 160000/160000 [==============================] - 35s 218us/step - loss: 7.1463e-05 - val_loss: 7.5949e-05
#
# Epoch 00008: val_loss did not improve from 0.00007
# Epoch 9/200
# 160000/160000 [==============================] - 34s 216us/step - loss: 7.0878e-05 - val_loss: 7.6134e-05
#
# Epoch 00009: val_loss did not improve from 0.00007
# Epoch 10/200
# 160000/160000 [==============================] - 34s 214us/step - loss: 7.0295e-05 - val_loss: 7.1813e-05
#
# Epoch 00010: val_loss did not improve from 0.00007
# Epoch 11/200
# 160000/160000 [==============================] - 34s 214us/step - loss: 7.0168e-05 - val_loss: 6.7291e-05
#
# Epoch 00011: val_loss improved from 0.00007 to 0.00007, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 12/200
# 160000/160000 [==============================] - 34s 211us/step - loss: 6.9729e-05 - val_loss: 6.7250e-05
#
# Epoch 00012: val_loss improved from 0.00007 to 0.00007, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 13/200
# 160000/160000 [==============================] - 35s 219us/step - loss: 6.9279e-05 - val_loss: 7.3727e-05
#
# Epoch 00013: val_loss did not improve from 0.00007
# Epoch 14/200
# 160000/160000 [==============================] - 36s 223us/step - loss: 6.8913e-05 - val_loss: 6.5827e-05
#
# Epoch 00014: val_loss improved from 0.00007 to 0.00007, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 15/200
# 160000/160000 [==============================] - 35s 218us/step - loss: 6.8776e-05 - val_loss: 6.2055e-05
#
# Epoch 00015: val_loss improved from 0.00007 to 0.00006, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 16/200
# 160000/160000 [==============================] - 35s 218us/step - loss: 6.8143e-05 - val_loss: 6.9506e-05
#
# Epoch 00016: val_loss did not improve from 0.00006
# Epoch 17/200
# 160000/160000 [==============================] - 32s 202us/step - loss: 6.7975e-05 - val_loss: 7.2336e-05
#
# Epoch 00017: val_loss did not improve from 0.00006
# Epoch 18/200
# 160000/160000 [==============================] - 33s 206us/step - loss: 6.7632e-05 - val_loss: 6.2984e-05
#
# Epoch 00018: val_loss did not improve from 0.00006
# Epoch 19/200
# 160000/160000 [==============================] - 35s 217us/step - loss: 6.7496e-05 - val_loss: 6.1397e-050s - loss: 6
#
# Epoch 00019: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 20/200
# 160000/160000 [==============================] - 32s 202us/step - loss: 6.7576e-05 - val_loss: 6.1619e-05
#
# Epoch 00020: val_loss did not improve from 0.00006
# Epoch 21/200
# 160000/160000 [==============================] - 32s 202us/step - loss: 6.7023e-05 - val_loss: 6.5407e-05
#
# Epoch 00021: val_loss did not improve from 0.00006
# Epoch 22/200
# 160000/160000 [==============================] - 33s 203us/step - loss: 6.6740e-05 - val_loss: 6.0674e-05
#
# Epoch 00022: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 23/200
# 160000/160000 [==============================] - 31s 195us/step - loss: 6.6648e-05 - val_loss: 6.3788e-05
#
# Epoch 00023: val_loss did not improve from 0.00006
# Epoch 24/200
# 160000/160000 [==============================] - 33s 203us/step - loss: 6.6640e-05 - val_loss: 6.5192e-05
#
# Epoch 00024: val_loss did not improve from 0.00006
# Epoch 25/200
# 160000/160000 [==============================] - 32s 200us/step - loss: 6.6491e-05 - val_loss: 6.1960e-05
#
# Epoch 00025: val_loss did not improve from 0.00006
# Epoch 26/200
# 160000/160000 [==============================] - 33s 208us/step - loss: 6.6466e-05 - val_loss: 6.9825e-05
#
# Epoch 00026: val_loss did not improve from 0.00006
# Epoch 27/200
# 160000/160000 [==============================] - 32s 202us/step - loss: 6.6168e-05 - val_loss: 6.1295e-05
#
# Epoch 00027: val_loss did not improve from 0.00006
# Epoch 28/200
# 160000/160000 [==============================] - 33s 208us/step - loss: 6.6109e-05 - val_loss: 7.0971e-05
#
# Epoch 00028: val_loss did not improve from 0.00006
# Epoch 29/200
# 160000/160000 [==============================] - 32s 203us/step - loss: 6.5517e-05 - val_loss: 6.8051e-05
#
# Epoch 00029: val_loss did not improve from 0.00006
# Epoch 30/200
# 160000/160000 [==============================] - 32s 202us/step - loss: 6.5374e-05 - val_loss: 6.6139e-05
#
# Epoch 00030: val_loss did not improve from 0.00006
# Epoch 31/200
# 160000/160000 [==============================] - 33s 208us/step - loss: 6.5266e-05 - val_loss: 6.3555e-05
#
# Epoch 00031: val_loss did not improve from 0.00006
# Epoch 32/200
# 160000/160000 [==============================] - 31s 192us/step - loss: 6.5319e-05 - val_loss: 6.0348e-05
#
# Epoch 00032: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 33/200
# 160000/160000 [==============================] - 32s 199us/step - loss: 6.5062e-05 - val_loss: 6.3218e-05
#
# Epoch 00033: val_loss did not improve from 0.00006
# Epoch 34/200
# 160000/160000 [==============================] - 31s 196us/step - loss: 6.5079e-05 - val_loss: 6.3654e-05
#
# Epoch 00034: val_loss did not improve from 0.00006
# Epoch 35/200
# 160000/160000 [==============================] - 32s 198us/step - loss: 6.4682e-05 - val_loss: 5.9710e-05
#
# Epoch 00035: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 36/200
# 160000/160000 [==============================] - 32s 200us/step - loss: 6.4485e-05 - val_loss: 6.0544e-05
#
# Epoch 00036: val_loss did not improve from 0.00006
# Epoch 37/200
# 160000/160000 [==============================] - 31s 191us/step - loss: 6.4501e-05 - val_loss: 6.1784e-05
#
# Epoch 00037: val_loss did not improve from 0.00006
# Epoch 38/200
# 160000/160000 [==============================] - 31s 197us/step - loss: 6.4486e-05 - val_loss: 8.0469e-05
#
# Epoch 00038: val_loss did not improve from 0.00006
# Epoch 39/200
# 160000/160000 [==============================] - 33s 207us/step - loss: 6.4456e-05 - val_loss: 5.9351e-05
#
# Epoch 00039: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 40/200
# 160000/160000 [==============================] - 32s 197us/step - loss: 6.4190e-05 - val_loss: 6.6173e-05
#
# Epoch 00040: val_loss did not improve from 0.00006
# Epoch 41/200
# 160000/160000 [==============================] - 33s 204us/step - loss: 6.4204e-05 - val_loss: 7.2882e-05
#
# Epoch 00041: val_loss did not improve from 0.00006
# Epoch 42/200
# 160000/160000 [==============================] - 34s 210us/step - loss: 6.3983e-05 - val_loss: 5.9767e-05
#
# Epoch 00042: val_loss did not improve from 0.00006
# Epoch 43/200
# 160000/160000 [==============================] - 25s 155us/step - loss: 6.4052e-05 - val_loss: 5.9647e-05
#
# Epoch 00043: val_loss did not improve from 0.00006
# Epoch 44/200
# 160000/160000 [==============================] - 26s 164us/step - loss: 6.3920e-05 - val_loss: 6.1235e-05
#
# Epoch 00044: val_loss did not improve from 0.00006
# Epoch 45/200
# 160000/160000 [==============================] - 27s 171us/step - loss: 6.3917e-05 - val_loss: 6.0238e-05
#
# Epoch 00045: val_loss did not improve from 0.00006
# Epoch 46/200
# 160000/160000 [==============================] - 26s 165us/step - loss: 6.3788e-05 - val_loss: 6.7681e-05
#
# Epoch 00046: val_loss did not improve from 0.00006
# Epoch 47/200
# 160000/160000 [==============================] - 27s 170us/step - loss: 6.3560e-05 - val_loss: 5.9578e-05
#
# Epoch 00047: val_loss did not improve from 0.00006
# Epoch 48/200
# 160000/160000 [==============================] - 29s 178us/step - loss: 6.3583e-05 - val_loss: 5.9955e-05
#
# Epoch 00048: val_loss did not improve from 0.00006
# Epoch 49/200
# 160000/160000 [==============================] - 26s 162us/step - loss: 6.3250e-05 - val_loss: 6.5644e-05
#
# Epoch 00049: val_loss did not improve from 0.00006
# Epoch 50/200
# 160000/160000 [==============================] - 27s 167us/step - loss: 6.3495e-05 - val_loss: 5.9351e-05
#
# Epoch 00050: val_loss did not improve from 0.00006
# Epoch 51/200
# 160000/160000 [==============================] - 28s 174us/step - loss: 6.2983e-05 - val_loss: 6.1889e-05
#
# Epoch 00051: val_loss did not improve from 0.00006
# Epoch 52/200
# 160000/160000 [==============================] - 31s 194us/step - loss: 6.3032e-05 - val_loss: 6.5457e-05
#
# Epoch 00052: val_loss did not improve from 0.00006
# Epoch 53/200
# 160000/160000 [==============================] - 29s 181us/step - loss: 6.3206e-05 - val_loss: 6.5180e-05
#
# Epoch 00053: val_loss did not improve from 0.00006
# Epoch 54/200
# 160000/160000 [==============================] - 30s 185us/step - loss: 6.2840e-05 - val_loss: 5.8831e-05
#
# Epoch 00054: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 55/200
# 160000/160000 [==============================] - 30s 188us/step - loss: 6.3039e-05 - val_loss: 5.9429e-05
#
# Epoch 00055: val_loss did not improve from 0.00006
# Epoch 56/200
# 160000/160000 [==============================] - 29s 182us/step - loss: 6.2363e-05 - val_loss: 6.7382e-05
#
# Epoch 00056: val_loss did not improve from 0.00006
# Epoch 57/200
# 160000/160000 [==============================] - 28s 174us/step - loss: 6.1694e-05 - val_loss: 5.8350e-05
#
# Epoch 00057: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 58/200
# 160000/160000 [==============================] - 27s 172us/step - loss: 6.0129e-05 - val_loss: 5.5555e-05
#
# Epoch 00058: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 59/200
# 160000/160000 [==============================] - 27s 169us/step - loss: 5.8901e-05 - val_loss: 5.9831e-05
#
# Epoch 00059: val_loss did not improve from 0.00006
# Epoch 60/200
# 160000/160000 [==============================] - 26s 164us/step - loss: 5.8144e-05 - val_loss: 5.6074e-05
#
# Epoch 00060: val_loss did not improve from 0.00006
# Epoch 61/200
# 160000/160000 [==============================] - 28s 173us/step - loss: 5.7094e-05 - val_loss: 6.1248e-05
#
# Epoch 00061: val_loss did not improve from 0.00006
# Epoch 62/200
# 160000/160000 [==============================] - 28s 175us/step - loss: 5.6712e-05 - val_loss: 5.1741e-05
#
# Epoch 00062: val_loss improved from 0.00006 to 0.00005, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 63/200
# 160000/160000 [==============================] - 27s 170us/step - loss: 5.6074e-05 - val_loss: 5.8991e-05
#
# Epoch 00063: val_loss did not improve from 0.00005
# Epoch 64/200
# 160000/160000 [==============================] - 27s 168us/step - loss: 5.5009e-05 - val_loss: 5.4771e-05
#
# Epoch 00064: val_loss did not improve from 0.00005
# Epoch 65/200
# 160000/160000 [==============================] - 27s 168us/step - loss: 5.1938e-05 - val_loss: 4.6574e-05
#
# Epoch 00065: val_loss improved from 0.00005 to 0.00005, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 66/200
# 160000/160000 [==============================] - 27s 171us/step - loss: 4.6343e-05 - val_loss: 4.3873e-05
#
# Epoch 00066: val_loss improved from 0.00005 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 67/200
# 160000/160000 [==============================] - 26s 165us/step - loss: 4.5555e-05 - val_loss: 4.3833e-05
#
# Epoch 00067: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 68/200
# 160000/160000 [==============================] - 31s 192us/step - loss: 4.5512e-05 - val_loss: 4.2333e-05
#
# Epoch 00068: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 69/200
# 160000/160000 [==============================] - 28s 173us/step - loss: 4.5218e-05 - val_loss: 4.2524e-05
#
# Epoch 00069: val_loss did not improve from 0.00004
# Epoch 70/200
# 160000/160000 [==============================] - 26s 161us/step - loss: 4.5257e-05 - val_loss: 4.3601e-05
#
# Epoch 00070: val_loss did not improve from 0.00004
# Epoch 71/200
# 160000/160000 [==============================] - 26s 161us/step - loss: 4.4946e-05 - val_loss: 4.2365e-05
#
# Epoch 00071: val_loss did not improve from 0.00004
# Epoch 72/200
# 160000/160000 [==============================] - 26s 163us/step - loss: 4.4876e-05 - val_loss: 4.2254e-05
#
# Epoch 00072: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 73/200
# 160000/160000 [==============================] - 26s 162us/step - loss: 4.4748e-05 - val_loss: 4.6120e-05
#
# Epoch 00073: val_loss did not improve from 0.00004
# Epoch 74/200
# 160000/160000 [==============================] - 26s 165us/step - loss: 4.4738e-05 - val_loss: 4.0638e-05
#
# Epoch 00074: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 75/200
# 160000/160000 [==============================] - 26s 160us/step - loss: 4.4585e-05 - val_loss: 4.3871e-05
#
# Epoch 00075: val_loss did not improve from 0.00004
# Epoch 76/200
# 160000/160000 [==============================] - 28s 173us/step - loss: 4.4869e-05 - val_loss: 4.5775e-05
#
# Epoch 00076: val_loss did not improve from 0.00004
# Epoch 77/200
# 160000/160000 [==============================] - 28s 175us/step - loss: 4.4633e-05 - val_loss: 3.9750e-05
#
# Epoch 00077: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 78/200
# 160000/160000 [==============================] - 27s 167us/step - loss: 4.4662e-05 - val_loss: 4.5582e-05
#
# Epoch 00078: val_loss did not improve from 0.00004
# Epoch 79/200
# 160000/160000 [==============================] - 25s 158us/step - loss: 4.4394e-05 - val_loss: 4.3536e-05
#
# Epoch 00079: val_loss did not improve from 0.00004
# Epoch 80/200
# 160000/160000 [==============================] - 27s 170us/step - loss: 4.4441e-05 - val_loss: 4.7954e-05
# Epoch 00080: val_loss did not improve from 0.00004
# Epoch 81/200
# 160000/160000 [==============================] - 28s 176us/step - loss: 4.4618e-05 - val_loss: 4.4386e-05
#
# Epoch 00081: val_loss did not improve from 0.00004
# Epoch 82/200
# 160000/160000 [==============================] - 26s 162us/step - loss: 4.4537e-05 - val_loss: 4.4499e-05
#
# Epoch 00082: val_loss did not improve from 0.00004
# Epoch 83/200
# 160000/160000 [==============================] - 26s 163us/step - loss: 4.4364e-05 - val_loss: 4.0290e-05
#
# Epoch 00083: val_loss did not improve from 0.00004
# Epoch 84/200
# 160000/160000 [==============================] - 30s 187us/step - loss: 4.4365e-05 - val_loss: 5.4163e-05
#
# Epoch 00084: val_loss did not improve from 0.00004
# Epoch 85/200
# 160000/160000 [==============================] - 25s 158us/step - loss: 4.4512e-05 - val_loss: 3.9935e-05
#
# Epoch 00085: val_loss did not improve from 0.00004
# Epoch 86/200
# 160000/160000 [==============================] - 26s 164us/step - loss: 4.4353e-05 - val_loss: 4.3214e-05
#
# Epoch 00086: val_loss did not improve from 0.00004
# Epoch 87/200
# 160000/160000 [==============================] - 27s 169us/step - loss: 4.4526e-05 - val_loss: 5.6369e-05
#
# Epoch 00087: val_loss did not improve from 0.00004
# Epoch 88/200
# 160000/160000 [==============================] - 27s 166us/step - loss: 4.4322e-05 - val_loss: 4.2319e-05
#
# Epoch 00088: val_loss did not improve from 0.00004
# Epoch 89/200
# 160000/160000 [==============================] - 24s 150us/step - loss: 4.4286e-05 - val_loss: 4.7507e-05
#
# Epoch 00089: val_loss did not improve from 0.00004
# Epoch 90/200
# 160000/160000 [==============================] - 21s 130us/step - loss: 4.4111e-05 - val_loss: 4.0748e-05
#
# Epoch 00090: val_loss did not improve from 0.00004
# Epoch 91/200
# 160000/160000 [==============================] - 21s 133us/step - loss: 4.4115e-05 - val_loss: 4.0932e-05
#
# Epoch 00091: val_loss did not improve from 0.00004
# Epoch 92/200
# 160000/160000 [==============================] - 22s 136us/step - loss: 4.4327e-05 - val_loss: 4.2746e-05
#
# Epoch 00092: val_loss did not improve from 0.00004
# Epoch 93/200
# 160000/160000 [==============================] - 21s 134us/step - loss: 4.4161e-05 - val_loss: 4.1554e-05
#
# Epoch 00093: val_loss did not improve from 0.00004
# Epoch 94/200
# 160000/160000 [==============================] - 20s 124us/step - loss: 4.4096e-05 - val_loss: 4.5759e-05
#
# Epoch 00094: val_loss did not improve from 0.00004
# Epoch 95/200
# 160000/160000 [==============================] - 20s 127us/step - loss: 4.4105e-05 - val_loss: 4.5243e-05
#
# Epoch 00095: val_loss did not improve from 0.00004
# Epoch 96/200
# 160000/160000 [==============================] - 20s 127us/step - loss: 4.3997e-05 - val_loss: 3.9634e-05
#
# Epoch 00096: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 97/200
# 160000/160000 [==============================] - 21s 129us/step - loss: 4.4042e-05 - val_loss: 4.0721e-05
#
# Epoch 00097: val_loss did not improve from 0.00004
# Epoch 98/200
# 160000/160000 [==============================] - 21s 131us/step - loss: 4.3878e-05 - val_loss: 4.4299e-05
#
# Epoch 00098: val_loss did not improve from 0.00004
# Epoch 99/200
# 160000/160000 [==============================] - 23s 146us/step - loss: 4.4026e-05 - val_loss: 4.2070e-05
#
# Epoch 00099: val_loss did not improve from 0.00004
# Epoch 100/200
# 160000/160000 [==============================] - 25s 157us/step - loss: 4.4139e-05 - val_loss: 4.1020e-05
#
# Epoch 00100: val_loss did not improve from 0.00004
# Epoch 101/200
# 160000/160000 [==============================] - 26s 161us/step - loss: 4.3756e-05 - val_loss: 5.6547e-05
#
# Epoch 00101: val_loss did not improve from 0.00004
# Epoch 102/200
# 160000/160000 [==============================] - 24s 152us/step - loss: 4.3828e-05 - val_loss: 4.1998e-05
#
# Epoch 00102: val_loss did not improve from 0.00004
# Epoch 103/200
# 160000/160000 [==============================] - 24s 148us/step - loss: 4.3842e-05 - val_loss: 4.2027e-05
#
# Epoch 00103: val_loss did not improve from 0.00004
# Epoch 104/200
# 160000/160000 [==============================] - 28s 178us/step - loss: 4.3806e-05 - val_loss: 4.0453e-05
#
# Epoch 00104: val_loss did not improve from 0.00004
# Epoch 105/200
# 160000/160000 [==============================] - 27s 167us/step - loss: 4.3830e-05 - val_loss: 4.1783e-05
#
# Epoch 00105: val_loss did not improve from 0.00004
# Epoch 106/200
# 160000/160000 [==============================] - 21s 129us/step - loss: 4.3825e-05 - val_loss: 4.7007e-05
#
# Epoch 00106: val_loss did not improve from 0.00004
# Epoch 107/200
# 160000/160000 [==============================] - 18s 115us/step - loss: 4.3768e-05 - val_loss: 4.1021e-05
#
# Epoch 00107: val_loss did not improve from 0.00004
# Epoch 108/200
# 160000/160000 [==============================] - 21s 129us/step - loss: 4.3640e-05 - val_loss: 4.3044e-05
#
# Epoch 00108: val_loss did not improve from 0.00004
# Epoch 109/200
# 160000/160000 [==============================] - 23s 142us/step - loss: 4.3690e-05 - val_loss: 3.9888e-05
#
# Epoch 00109: val_loss did not improve from 0.00004
# Epoch 110/200
# 160000/160000 [==============================] - 22s 139us/step - loss: 4.3847e-05 - val_loss: 4.1077e-05
#
# Epoch 00110: val_loss did not improve from 0.00004
# Epoch 111/200
# 160000/160000 [==============================] - 21s 134us/step - loss: 4.3762e-05 - val_loss: 3.9739e-05
#
# Epoch 00111: val_loss did not improve from 0.00004
# Epoch 112/200
# 160000/160000 [==============================] - 22s 136us/step - loss: 4.3805e-05 - val_loss: 4.0817e-05
#
# Epoch 00112: val_loss did not improve from 0.00004
# Epoch 113/200
# 160000/160000 [==============================] - 22s 137us/step - loss: 4.3477e-05 - val_loss: 4.0720e-05
#
# Epoch 00113: val_loss did not improve from 0.00004
# Epoch 114/200
# 160000/160000 [==============================] - 21s 132us/step - loss: 4.3490e-05 - val_loss: 4.2075e-05
#
# Epoch 00114: val_loss did not improve from 0.00004
# Epoch 115/200
# 160000/160000 [==============================] - 22s 135us/step - loss: 4.3441e-05 - val_loss: 4.0276e-05
#
# Epoch 00115: val_loss did not improve from 0.00004
# Epoch 116/200
# 160000/160000 [==============================] - 21s 130us/step - loss: 4.3487e-05 - val_loss: 4.3195e-05
#
# Epoch 00116: val_loss did not improve from 0.00004
# Epoch 117/200
# 160000/160000 [==============================] - 21s 132us/step - loss: 4.3404e-05 - val_loss: 4.9095e-05
#
# Epoch 00117: val_loss did not improve from 0.00004
# Epoch 118/200
# 160000/160000 [==============================] - 20s 128us/step - loss: 4.3577e-05 - val_loss: 4.1912e-05
#
# Epoch 00118: val_loss did not improve from 0.00004
# Epoch 119/200
# 160000/160000 [==============================] - 21s 130us/step - loss: 4.3481e-05 - val_loss: 4.3607e-05
#
# Epoch 00119: val_loss did not improve from 0.00004
# Epoch 120/200
# 160000/160000 [==============================] - 23s 142us/step - loss: 4.3618e-05 - val_loss: 3.9594e-05
#
# Epoch 00120: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 121/200
# 160000/160000 [==============================] - 23s 141us/step - loss: 4.3424e-05 - val_loss: 4.2848e-05
#
# Epoch 00121: val_loss did not improve from 0.00004
# Epoch 122/200
# 160000/160000 [==============================] - 21s 132us/step - loss: 4.3420e-05 - val_loss: 4.3170e-05
#
# Epoch 00122: val_loss did not improve from 0.00004
# Epoch 123/200
# 160000/160000 [==============================] - 31s 195us/step - loss: 4.3279e-05 - val_loss: 3.9075e-05
#
# Epoch 00125: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 126/200
# 160000/160000 [==============================] - 31s 192us/step - loss: 4.3264e-05 - val_loss: 4.3893e-05
#
# Epoch 00126: val_loss did not improve from 0.00004
# Epoch 127/200
# 160000/160000 [==============================] - 29s 182us/step - loss: 4.3268e-05 - val_loss: 4.0005e-05s -  - ETA: 0s - loss: 4.3267e-0
#
# Epoch 00127: val_loss did not improve from 0.00004
# Epoch 128/200
# 160000/160000 [==============================] - 29s 183us/step - loss: 4.3160e-05 - val_loss: 4.8643e-05
#
# Epoch 00128: val_loss did not improve from 0.00004
# Epoch 129/200
# 160000/160000 [==============================] - 30s 188us/step - loss: 4.3361e-05 - val_loss: 4.1029e-05
#
# Epoch 00129: val_loss did not improve from 0.00004
# Epoch 130/200
# 160000/160000 [==============================] - 31s 192us/step - loss: 4.3278e-05 - val_loss: 4.0254e-05
#
# Epoch 00130: val_loss did not improve from 0.00004
# Epoch 131/200
# 160000/160000 [==============================] - 30s 187us/step - loss: 4.3111e-05 - val_loss: 3.9611e-05
#
# Epoch 00131: val_loss did not improve from 0.00004
# Epoch 132/200
# 160000/160000 [==============================] - 30s 185us/step - loss: 4.3113e-05 - val_loss: 4.3706e-05
#
# Epoch 00132: val_loss did not improve from 0.00004
# Epoch 133/200
# 160000/160000 [==============================] - 29s 180us/step - loss: 4.3252e-05 - val_loss: 6.6738e-05
#
# Epoch 00133: val_loss did not improve from 0.00004
# Epoch 134/200
# 160000/160000 [==============================] - 30s 186us/step - loss: 4.3039e-05 - val_loss: 4.0584e-051s
#
# Epoch 00134: val_loss did not improve from 0.00004
# Epoch 135/200
# 160000/160000 [==============================] - 29s 181us/step - loss: 4.2895e-05 - val_loss: 4.1435e-05
#
# Epoch 00135: val_loss did not improve from 0.00004
# Epoch 136/200
# 160000/160000 [==============================] - 32s 203us/step - loss: 4.2977e-05 - val_loss: 6.2886e-05
#
# Epoch 00136: val_loss did not improve from 0.00004
# Epoch 137/200
# 160000/160000 [==============================] - 32s 202us/step - loss: 4.2791e-05 - val_loss: 4.0115e-05
#
# Epoch 00137: val_loss did not improve from 0.00004
# Epoch 138/200
# 160000/160000 [==============================] - 33s 206us/step - loss: 4.2657e-05 - val_loss: 4.9519e-05
#
# Epoch 00138: val_loss did not improve from 0.00004
# Epoch 139/200
# 160000/160000 [==============================] - 33s 207us/step - loss: 4.1928e-05 - val_loss: 4.1069e-05
#
# Epoch 00145: val_loss did not improve from 0.00004
# Epoch 146/200
# 160000/160000 [==============================] - 30s 187us/step - loss: 4.2046e-05 - val_loss: 5.4165e-05
#
# Epoch 00146: val_loss did not improve from 0.00004
# Epoch 147/200
# 160000/160000 [==============================] - 29s 183us/step - loss: 4.2105e-05 - val_loss: 4.8247e-054.201 - ETA: 2s - loss: 4 - ETA: 2s - l - ETA: 1s - loss: 4.2072e- -
#
# Epoch 00147: val_loss did not improve from 0.00004
# Epoch 148/200
# 160000/160000 [==============================] - 31s 194us/step - loss: 4.1791e-05 - val_loss: 4.2494e-05
#
# Epoch 00148: val_loss did not improve from 0.00004
# Epoch 149/200
# 160000/160000 [==============================] - 20s 122us/step - loss: 4.1593e-05 - val_loss: 3.8969e-05
#
# Epoch 00177: val_loss did not improve from 0.00004
# Epoch 178/200
# 160000/160000 [==============================] - 23s 145us/step - loss: 4.1633e-05 - val_loss: 3.9293e-05
#
# Epoch 00178: val_loss did not improve from 0.00004
# Epoch 179/200
# 160000/160000 [==============================] - 24s 151us/step - loss: 4.1672e-05 - val_loss: 4.3856e-05
#
# Epoch 00179: val_loss did not improve from 0.00004
# Epoch 180/200
# 160000/160000 [==============================] - 24s 150us/step - loss: 4.1716e-05 - val_loss: 3.9516e-05
#
# Epoch 00180: val_loss did not improve from 0.00004
# Epoch 181/200
# 160000/160000 [==============================] - 23s 146us/step - loss: 4.1577e-05 - val_loss: 4.1267e-05
#
# Epoch 00181: val_loss did not improve from 0.00004
# Epoch 182/200
# 160000/160000 [==============================] - 23s 144us/step - loss: 4.1733e-05 - val_loss: 4.3630e-05
#
# Epoch 00182: val_loss did not improve from 0.00004
# Epoch 183/200
# 160000/160000 [==============================] - 21s 132us/step - loss: 4.1747e-05 - val_loss: 4.1095e-05
#
# Epoch 00183: val_loss did not improve from 0.00004
# Epoch 184/200
# 160000/160000 [==============================] - 22s 139us/step - loss: 4.1598e-05 - val_loss: 3.9100e-05
#
# Epoch 00184: val_loss did not improve from 0.00004
# Epoch 185/200
# 160000/160000 [==============================] - 21s 131us/step - loss: 4.1531e-05 - val_loss: 3.8914e-05
#
# Epoch 00185: val_loss did not improve from 0.00004
# Epoch 186/200
# 160000/160000 [==============================] - 18s 115us/step - loss: 4.1689e-05 - val_loss: 4.1124e-05
#
# Epoch 00186: val_loss did not improve from 0.00004
# Epoch 187/200
# 160000/160000 [==============================] - 19s 119us/step - loss: 4.1601e-05 - val_loss: 4.1810e-05
#
# Epoch 00187: val_loss did not improve from 0.00004
# Epoch 188/200
# 160000/160000 [==============================] - 20s 125us/step - loss: 4.1697e-05 - val_loss: 3.9546e-05
#
# Epoch 00188: val_loss did not improve from 0.00004
# Epoch 189/200
# 160000/160000 [==============================] - 21s 129us/step - loss: 4.1689e-05 - val_loss: 3.8197e-05
#
# Epoch 00189: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 190/200
# 160000/160000 [==============================] - 23s 141us/step - loss: 4.1755e-05 - val_loss: 4.5301e-05
#
# Epoch 00190: val_loss did not improve from 0.00004
# Epoch 191/200
# 160000/160000 [==============================] - 24s 147us/step - loss: 4.1478e-05 - val_loss: 4.1113e-05
#
# Epoch 00191: val_loss did not improve from 0.00004
# Epoch 192/200
# 160000/160000 [==============================] - 21s 130us/step - loss: 4.1460e-05 - val_loss: 4.3620e-05
#
# Epoch 00192: val_loss did not improve from 0.00004
# Epoch 193/200
# 160000/160000 [==============================] - 19s 121us/step - loss: 4.1597e-05 - val_loss: 3.9006e-05
#
# Epoch 00193: val_loss did not improve from 0.00004
# Epoch 194/200
# 160000/160000 [==============================] - 20s 123us/step - loss: 4.1691e-05 - val_loss: 5.1478e-05
#
# Epoch 00194: val_loss did not improve from 0.00004
# Epoch 195/200
# 160000/160000 [==============================] - 18s 113us/step - loss: 4.1561e-05 - val_loss: 4.0768e-05
#
# Epoch 00195: val_loss did not improve from 0.00004
# Epoch 196/200
# 160000/160000 [==============================] - 18s 110us/step - loss: 4.1680e-05 - val_loss: 4.2346e-05
#
# Epoch 00196: val_loss did not improve from 0.00004
# Epoch 197/200
# 160000/160000 [==============================] - 19s 118us/step - loss: 4.1442e-05 - val_loss: 3.8821e-05
#
# Epoch 00197: val_loss did not improve from 0.00004
# Epoch 198/200
# 160000/160000 [==============================] - 19s 121us/step - loss: 4.1475e-05 - val_loss: 3.9225e-05
#
# Epoch 00198: val_loss did not improve from 0.00004
# Epoch 199/200
# 160000/160000 [==============================] - 20s 125us/step - loss: 4.1421e-05 - val_loss: 3.9020e-05
#
# Epoch 00199: val_loss did not improve from 0.00004
# Epoch 200/200
# 160000/160000 [==============================] - 19s 120us/step - loss: 4.1469e-05 - val_loss: 3.9317e-05
#
# Epoch 00200: val_loss did not improve from 0.00004

# %%
nn5_scint_decays=np.linspace(15,50,10)
nn5_ratios=np.linspace(-25,25,10)
nn5_eventsperexperiment=500
nn5_results, nn5_actual_values, nn5_labels=model_verifier('NarrowerParameterSpace500events1000photons100binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %%
fig, ax = plt.subplots(10, 10)


for i in reversed(range(100)):
    #print(i)
    ax = plt.subplot(10,10,i+1)
    ax.hist([item[0] for item in nn5_profile[99-i]])
    
    



fig.set_size_inches(20,20)
plt.tight_layout()
#(plt.hist([item[0] for item in nn5_profile[22]]))



plt.figure()
fig, ax = plt.subplots(10, 10)


for i in reversed(range(100)):
    #print(i)
    ax = plt.subplot(10,10,i+1)
    ax.hist([item[1] for item in nn5_profile[99-i]])
fig.set_size_inches(20,20)
plt.tight_layout()

# %% [markdown]
# # 10,000 photon model on 5,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('NarrowerParameterSpace500events5000photons100binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %% [markdown]
# # 10,000 photon model on 1,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('NarrowerParameterSpace500events1000photons100binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %% [markdown]
# # 10,000 photon model on 2,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('NarrowerParameterSpace500events2000photons100binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %% [markdown]
# # 10,000 photon model on 3,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('NarrowerParameterSpace500events3000photons100binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %% [markdown]
# # 10,000 photon model on 4,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('NarrowerParameterSpace500events4000photons100binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons100binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %%
print('h')
# Out:
# h

# %%
pulse=Pulse(1000,10,25)

# %%
a,b,c,d=pulse.output2()

# %%
vals=[]

for i in range(len(b)-1):
    vals.append((b[i]+b[i+1])/2)

# %%
print(len(np.linspace(0,250,100)))

# %%
print(vals)

# %%
pulse=Pulse(5000,10,50)
a,b,c,d=pulse.output2()

pulse.graph_both_pulses()


pulse.graph_pdf()

vals=[]

for i in range(len(b)-1):
    vals.append((b[i]+b[i+1])/2)


plt.figure()
plt.bar(vals,a, width=5)
plt.title("Example Histogram")
# Out:
# Text(0.5,1,'Example Histogram')

# %%
pulse=Pulse(5000,-10,50)
a,b,c,d=pulse.output2()

pulse.graph_both_pulses()


pulse.graph_pdf()

vals=[]

for i in range(len(b)-1):
    vals.append((b[i]+b[i+1])/2)


plt.figure()
plt.bar(vals,a, width=5)
plt.title("Example Histogram")
# Out:
# Text(0.5,1,'Example Histogram')

# %%
pulse=Pulse(5000,25,15)
a,b,c,d=pulse.output2()

pulse.graph_both_pulses()


pulse.graph_pdf()

vals=[]

for i in range(len(b)-1):
    vals.append((b[i]+b[i+1])/2)


plt.figure()
plt.bar(vals,a, width=5)
plt.title("Example Histogram")
# Out:
# Text(0.5,1,'Example Histogram')

# %%
pulse=Pulse(5000,-25,15)
a,b,c,d=pulse.output2()

pulse.graph_both_pulses()


pulse.graph_pdf()

vals=[]

for i in range(len(b)-1):
    vals.append((b[i]+b[i+1])/2)


plt.figure()
plt.bar(vals,a, width=5)
plt.title("Example Histogram")
# Out:
# Text(0.5,1,'Example Histogram')

# %%
print(b)
# Out:
# [  0.    2.5   5.    7.5  10.   12.5  15.   17.5  20.   22.5  25.   27.5
#   30.   32.5  35.   37.5  40.   42.5  45.   47.5  50.   52.5  55.   57.5
#   60.   62.5  65.   67.5  70.   72.5  75.   77.5  80.   82.5  85.   87.5
#   90.   92.5  95.   97.5 100.  102.5 105.  107.5 110.  112.5 115.  117.5
#  120.  122.5 125.  127.5 130.  132.5 135.  137.5 140.  142.5 145.  147.5
#  150.  152.5 155.  157.5 160.  162.5 165.  167.5 170.  172.5 175.  177.5
#  180.  182.5 185.  187.5 190.  192.5 195.  197.5 200.  202.5 205.  207.5
#  210.  212.5 215.  217.5 220.  222.5 225.  227.5 230.  232.5 235.  237.5
#  240.  242.5 245.  247.5 250. ]

# %%
plt.bar(vals,a, width=5)
# Out:
# <BarContainer object of 100 artists>
