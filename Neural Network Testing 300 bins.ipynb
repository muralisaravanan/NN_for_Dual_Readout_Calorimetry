# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.signal as signal
import random
import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import utils
import h5py
import time
from sklearn.preprocessing import MinMaxScaler

from numpy.random import seed
seed(5)
from tensorflow import set_random_seed
set_random_seed(7)
'''
Based on work by Federico De Guio: https://github.com/deguio/ML4DQM/blob/master/notebooks/Semi_Supervised/AE_ssl_random_hotdead_size.ipynb
See: https://indico.cern.ch/event/783825/contributions/3261553/attachments/1789464/2914642/hcaldpg_fpga_ml_reco_01feb2019.pdf
for possible implementation into FPGA
'''
# Out:
# Using TensorFlow backend.
# '\nBased on work by Federico De Guio: https://github.com/deguio/ML4DQM/blob/master/notebooks/Semi_Supervised/AE_ssl_random_hotdead_size.ipynb\nSee: https://indico.cern.ch/event/783825/contributions/3261553/attachments/1789464/2914642/hcaldpg_fpga_ml_reco_01feb2019.pdf\nfor possible implementation into FPGA\n'

# %%
def plot_loss(data, title,yscale="linear"):     
    """ Plots the training and validation loss yscale can be: linear,log,symlog """
    plt.figure()
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(title)
    plt.plot(data.history["loss"])#, linestyle=line_styles[0], color=color_palette["Indigo"][900], linewidth=3)
    plt.plot(data.history["val_loss"])#, linestyle=line_styles[2], color=color_palette["Teal"][300], linewidth=3)
    plt.legend(["Train", "Validation"])#, loc="upper right", frameon=False)
    plt.yscale(yscale)
    plt.show();

# %%
class Pulse:
    '''
    A class that generates a Pulse that includes both Cerenkov and Scintillation Pulse. The pulse is randomly generated 
    through the use of a probability density function that is generated by the given parameters.
    The pulse has 512 samples and is identifiable by 3 parameters:
        1) ratio: If ratio is positive, it is the ratio of the Area of Cernekov:Area of Scintillation. 
                  If ratio is negative, it is the ratio of the Area of Scintillation:Area of Cerenkov
                
        This is altered by changing the height of the Cerenkov pulse (Cerenkov Radiation).
        
        
        2) separation: Time between the two pulses
       
    '''
    
    
    
    def __init__(self, photoelectrons, ratio, scint_decay):
        self.start=10
        self.rise=0.05
        self.cerenkov_decay=2.5
        self.scint_decay=scint_decay
        
        self.end_time=250
        self.timestep=0.1
        self.t=t=np.arange(0,self.end_time,self.timestep)
        self.bin_number=100
        

        if ratio>0:
            self.ratio=ratio
        else:
            self.ratio=-(1/ratio)
            
        self.photoelectrons=photoelectrons
        self.cerenkov_strength=self.ratio
        #self.cerenkov_percent=self.ratio/(self.ratio+1)
        #self.scint_percent=1/(self.ratio+1)
        self.interp=self.interpolator()
        self.cerenkov_area=sp.integrate.quad(self.cerenkov_scaled, self.start, self.end_time)
        self.scint_area=sp.integrate.quad(self.scintillation_normalized, self.start, self.end_time)
        
        self.cerenkov_percent=(self.cerenkov_area[0])/(self.cerenkov_area[0]+self.scint_area[0])
        self.scint_percent=(self.scint_area[0])/(self.cerenkov_area[0]+self.scint_area[0])
 
    def cerenkov(self,t):
        return (1-np.exp(-((t-self.start)/self.rise)))*(np.exp(-((t-self.start)/self.cerenkov_decay)))

    def scintillation(self, t):
        return (1-np.exp(-((t-self.start)/self.rise)))*(np.exp(-((t-self.start)/self.scint_decay)))
    
    def cerenkov_scaled(self, t):
        cerenkov=self.cerenkov(t)
        norm=sp.integrate.quad(self.cerenkov, self.start, self.end_time)
        return (1/norm[0])*self.cerenkov_strength*cerenkov
    
    def scintillation_normalized(self, t):
        scint=self.scintillation(t)
        norm=sp.integrate.quad(self.scintillation, self.start, self.end_time)
        return (1/norm[0])*scint


    def pulse_func_helper(self, time):
        if time<self.start:
            return 0
        else:
            return self.cerenkov_scaled(time) + self.scintillation_normalized(time) 
    
    
    def pulse_func(self, t):
        pulse=[]
                        
        for time in t:
            pulse.append(self.pulse_func_helper(time))
        return np.asarray(pulse)


    def randomValues(self,number):
        val=[]
        for x in range(number):
            val.append(random.random())
        return val

    
    def graph_both_pulses(self):
        t=np.arange(self.start,self.end_time,self.timestep)
        plt.figure()
        plt.plot(t, self.cerenkov_scaled(t), c='r', label="cerenkov")
        plt.plot(t, self.scintillation_normalized(t), label='scintillation')
        plt.xlabel("Time (ns)")
        plt.title("Pulse with ratio "+ str(self.ratio)+ " and scint decay "+str(self.scint_decay))
        plt.legend()
    
    def final_pdf(self, t):
        radiation=self.pulse_func(t)
        norm=sp.integrate.quad(self.pulse_func_helper, 0, self.end_time)
        return (1/norm[0])*radiation
    
    def graph_pdf(self):
        plt.figure()
        plt.plot(self.t, self.final_pdf(self.t))
        plt.xlabel("Time (ns)")
        plt.title("Pulse with ratio "+ str(self.ratio)+ " and scint decay "+str(self.scint_decay))

    def final_cdf(self, t):
        prob=self.final_pdf(t)
        return np.cumsum(prob)*self.timestep
    
    def interpolator(self):
        cumul=self.final_cdf(self.t)
        hits=self.photoelectrons
        #print(hits)
        rand=self.randomValues(hits)
        #print(rand)
        interp=sp.interpolate.interp1d(cumul,self.t, fill_value="extrapolate")
        return interp
    
    def output(self):
        hits=self.photoelectrons
        #print(hits)
        rand=self.randomValues(hits)
        vals=self.interp(rand)
        hist, bin_edges=np.histogram(vals, bins=self.bin_number, range=(0,self.end_time))
        return hist, self.cerenkov_percent, self.scint_percent
        

    
    '''
    DEPRECAYED FUNCTIONS
    def final_distribution(self):
        cumul=self.final_cdf(self.t)
        hits=self.photoelectrons
        #print(hits)
        rand=self.randomValues(hits)
        #print(rand)
        interp=sp.interpolate.interp1d(cumul,self.t, fill_value="extrapolate")
        vals=interp(rand)
        #print(vals)
        return vals
        
    def histogram_generator(self):
        data=self.final_distribution()
        hist, bin_edges=np.histogram(data, bins=self.bin_number, range=(0,self.end_time))
        #print(bin_edges)
        return hist
    
    def output(self):
        
        
        return self.histogram_generator(), self.cerenkov_percent, self.scint_percent
    '''

# %%
class PulseLibrary:
    '''
    Creates a list of pulses with the attached ratio.
    labels has form of ratioXXXscint_decayXXeventXX
    '''
    
    def __init__(self, seed, name, eventsperexperiment, photoelectrons,ratios=[1],scint_decays=[50]):
        np.random.seed(seed)
        self.name=name +'.hdf5'
        self.scint_decays=scint_decays
        self.ratios=ratios
        self.photoelectrons=photoelectrons
        self.eventsperexperiment=eventsperexperiment
        self.labels=[]
        self.pulses=[]
        self.inputs=[]
        self.outputs=[]
        
        
        
        file=h5py.File(self.name, 'w')
        
        for ratio in self.ratios:
            for scint_decay in self.scint_decays:
                pulse=Pulse(self.photoelectrons, ratio, scint_decay)
                
                group_name="ratio"+str(ratio)+"scintdecay"+str(scint_decay)
                
                group = file.create_group(group_name)
                
                for i in range(eventsperexperiment):
                    
                    self.pulses.append(pulse)
                    ins, out1, out2=pulse.output()
                    outs=[out1, out2]
                    
                    
                    label="ratio"+str(ratio)+"scintdecay"+str(scint_decay)+"event"+str(i)
                    self.labels.append(label)
                    self.inputs.append(ins)
                    self.outputs.append(outs)
                    
                    subgroup=group.create_group(label)
                    
                    
                    d1 = subgroup.create_dataset(label+'input', data=ins)
                    d2 = subgroup.create_dataset(label+'output', data=outs)
                    
        
        file.close()
    
    def get_inputs(self):
        return np.asarray(self.inputs)
    
    def get_outputs(self):
        return np.asarray(self.outputs)
    
    def get_labels(self):
        return self.labels
    
    def get_pulses(self):
        return np.asarray(self.pulses)

# %%
integration_vals=[1.25, 3.75, 6.25, 8.75, 11.25, 13.75, 16.25, 18.75, 21.25, 23.75, 26.25, 28.75, 31.25, 33.75, 36.25, 38.75, 41.25, 43.75, 46.25, 48.75, 51.25, 53.75, 56.25, 58.75, 61.25, 63.75, 66.25, 68.75, 71.25, 73.75, 76.25, 78.75, 81.25, 83.75, 86.25, 88.75, 91.25, 93.75, 96.25, 98.75, 101.25, 103.75, 106.25, 108.75, 111.25, 113.75, 116.25, 118.75, 121.25, 123.75, 126.25, 128.75, 131.25, 133.75, 136.25, 138.75, 141.25, 143.75, 146.25, 148.75, 151.25, 153.75, 156.25, 158.75, 161.25, 163.75, 166.25, 168.75, 171.25, 173.75, 176.25, 178.75, 181.25, 183.75, 186.25, 188.75, 191.25, 193.75, 196.25, 198.75, 201.25, 203.75, 206.25, 208.75, 211.25, 213.75, 216.25, 218.75, 221.25, 223.75, 226.25, 228.75, 231.25, 233.75, 236.25, 238.75, 241.25, 243.75, 246.25, 248.75]

# %%
def model_creator():
    model = Sequential()
    #model.add(Dense(50,  input_shape=(300,), kernel_initializer='normal', activation='relu'))
    model.add(Dense(10, input_shape=(300,), kernel_initializer='ones', activation='relu'))
    model.add(Dense(2, kernel_initializer='ones', activation='relu'))
# Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

def model_trainer(pulse_library, model_name):
    model=model_creator()
    file=h5py.File(pulse_library, 'r')
    X=[]
    Y=[]
    for groups in file.values():
        for subgroup in groups.values():
            for event in subgroup.values():
                #if not "ratio0.0scint"in event.name:
                #if 'event0' in event.name:  
                if event.name[-5:]=="input":
                    data=event[:]
                    data=np.asarray(data)                      
                    X.append(data)
                    #X.append(data)
                elif event.name[-6:]=="output":
                    Y.append(event[:])
    file.close()    
    X=np.asarray(X)

    Y=np.asarray(Y)
    norm_factor=np.amax(X)
    X_scaled=X/norm_factor
    Xtrain, Xval, Ytrain, Yval = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)
    checkpointer = ModelCheckpoint(filepath=model_name+"weights.hdf5",verbose=3, save_best_only=True)
    earlystop= EarlyStopping(monitor='val_loss', min_delta=0, patience=50 ,verbose=1, mode='auto')
    history=model.fit(Xtrain,Ytrain,epochs=200,verbose=1
                             ,validation_data=(Xval,Yval)
                             ,shuffle=True, batch_size=16
                             ,callbacks=[earlystop,checkpointer])
    model.save(model_name)
    return model, history

def model_verifier(pulse_library, model_name, ratios, scint_decays, eventsperexperiment):
    model=load_model(model_name)
    file=h5py.File(pulse_library, 'r')
    X=[]
    Y=[]
    labels=[]
    
    for ratio in ratios:
        for scint_decay in scint_decays:
            tempX=[]
            tempY=[]
            templabels=[]
            for i in range(eventsperexperiment):
                label="/ratio"+str(ratio)+"scintdecay"+str(scint_decay)+"/ratio"+str(ratio)+"scintdecay"+str(scint_decay)+"event"+str(i)+"/ratio"+str(ratio)+"scintdecay"+str(scint_decay)+"event"+str(i)
                #print(label)
                Xdata=file[label+"input"][:]
                Ydata=file[label+"output"][:]
                Xdata=np.asarray(Xdata)
                
                tempX.append(Xdata)
                tempY.append(Ydata)
                templabels.append(label)
            X.append(tempX)
            Y.append(tempY)
            labels.append(templabels)
    
    file.close()
    X=np.asarray(X)
    Y=np.asarray(Y)
    results=[]
    norm_factor=np.amax(X)
    X_scaled=X/norm_factor
    
    for x in X_scaled:
        prediction=model.predict(x)
        results.append(prediction)

    results=np.array(results)
    #results=model.predict(X)
    return results, Y, labels
    
    
    '''
    deprecated
    for groups in file.values():
        tempX=[]
        tempY=[]
        templabels=[]
        for subgroup in groups.values():
            
            for event in subgroup.values():
                if event.name[-5:]=="input":
                    tempX.append(event)
                    templabels.append(event.name)
                elif event.name[-6:]=="output":
                    tempY.append(event)
        X.append(tempX)
        Y.append(tempY)
        labels.append(templabels)
            
    X=np.asarray(X)
    Y=np.asarray(Y)
    results=[]
    for x in X:
        prediction=model.predict(x)
        results.append(prediction)
    results=np.array(results)
    #results=model.predict(X)
    return results, Y, labels
    '''

# %% [markdown]
# # 10,000 photoelectrons

# %%
nn5_scint_decays=np.linspace(15,50,10)
nn5_ratios=np.linspace(-25,25,10)
nn5_eventsperexperiment=500
nn5_model,nn5_history=model_trainer('FinerParameterSpace500events10000photons300binsTrainingLibrary_20x20.hdf5', 'NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5')
plot_loss(data=nn5_history,title="Loss vs Epoch for nn5",yscale='linear')
# Out:
# Train on 160000 samples, validate on 40000 samples
# Epoch 1/200
# 160000/160000 [==============================] - 34s 214us/step - loss: 36.6033 - val_loss: 0.1583
#
# Epoch 00001: val_loss improved from inf to 0.15828, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 2/200
# 160000/160000 [==============================] - 21s 132us/step - loss: 0.0440 - val_loss: 8.0359e-05
#
# Epoch 00002: val_loss improved from 0.15828 to 0.00008, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 3/200
# 160000/160000 [==============================] - 30s 187us/step - loss: 7.5838e-05 - val_loss: 8.3988e-05
#
# Epoch 00003: val_loss did not improve from 0.00008
# Epoch 4/200
# 160000/160000 [==============================] - 33s 207us/step - loss: 7.4165e-05 - val_loss: 7.0874e-05
#
# Epoch 00004: val_loss improved from 0.00008 to 0.00007, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 5/200
# 160000/160000 [==============================] - 28s 178us/step - loss: 7.3252e-05 - val_loss: 7.3071e-05
#
# Epoch 00005: val_loss did not improve from 0.00007
# Epoch 6/200
# 160000/160000 [==============================] - 26s 160us/step - loss: 7.2407e-05 - val_loss: 7.2339e-05
#
# Epoch 00006: val_loss did not improve from 0.00007
# Epoch 7/200
# 160000/160000 [==============================] - 22s 136us/step - loss: 7.2580e-05 - val_loss: 7.5492e-05
#
# Epoch 00007: val_loss did not improve from 0.00007
# Epoch 8/200
# 160000/160000 [==============================] - 20s 125us/step - loss: 7.1250e-05 - val_loss: 6.3052e-05
#
# Epoch 00008: val_loss improved from 0.00007 to 0.00006, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 9/200
# 160000/160000 [==============================] - 20s 125us/step - loss: 7.0203e-05 - val_loss: 6.5419e-05
#
# Epoch 00009: val_loss did not improve from 0.00006
# Epoch 10/200
# 160000/160000 [==============================] - 20s 122us/step - loss: 6.9631e-05 - val_loss: 7.0479e-05
#
# Epoch 00010: val_loss did not improve from 0.00006
# Epoch 11/200
# 160000/160000 [==============================] - 20s 124us/step - loss: 6.8979e-05 - val_loss: 6.1410e-05
#
# Epoch 00011: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 12/200
# 160000/160000 [==============================] - 20s 123us/step - loss: 6.8635e-05 - val_loss: 7.3617e-05
#
# Epoch 00012: val_loss did not improve from 0.00006
# Epoch 13/200
# 160000/160000 [==============================] - 23s 147us/step - loss: 6.8282e-05 - val_loss: 6.5258e-05
#
# Epoch 00013: val_loss did not improve from 0.00006
# Epoch 14/200
# 160000/160000 [==============================] - 18s 113us/step - loss: 6.7592e-05 - val_loss: 7.6658e-05
#
# Epoch 00014: val_loss did not improve from 0.00006
# Epoch 15/200
# 160000/160000 [==============================] - 20s 123us/step - loss: 6.6827e-05 - val_loss: 6.8352e-05
#
# Epoch 00015: val_loss did not improve from 0.00006
# Epoch 16/200
# 160000/160000 [==============================] - 22s 137us/step - loss: 6.6357e-05 - val_loss: 6.9049e-05
#
# Epoch 00016: val_loss did not improve from 0.00006
# Epoch 17/200
# 160000/160000 [==============================] - 25s 158us/step - loss: 6.6231e-05 - val_loss: 6.6340e-05
#
# Epoch 00017: val_loss did not improve from 0.00006
# Epoch 18/200
# 160000/160000 [==============================] - 35s 217us/step - loss: 6.5556e-05 - val_loss: 6.3475e-05
#
# Epoch 00018: val_loss did not improve from 0.00006
# Epoch 19/200
# 160000/160000 [==============================] - 58s 360us/step - loss: 6.5284e-05 - val_loss: 6.4787e-05
#
# Epoch 00019: val_loss did not improve from 0.00006
# Epoch 20/200
# 160000/160000 [==============================] - 34s 213us/step - loss: 6.5396e-05 - val_loss: 7.1242e-05
#
# Epoch 00020: val_loss did not improve from 0.00006
# Epoch 21/200
# 160000/160000 [==============================] - 36s 225us/step - loss: 6.4691e-05 - val_loss: 5.9403e-05
#
# Epoch 00021: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 22/200
# 160000/160000 [==============================] - 44s 274us/step - loss: 6.4829e-05 - val_loss: 6.7952e-05
#
# Epoch 00022: val_loss did not improve from 0.00006
# Epoch 23/200
# 160000/160000 [==============================] - 36s 226us/step - loss: 6.4953e-05 - val_loss: 6.5585e-05
#
# Epoch 00023: val_loss did not improve from 0.00006
# Epoch 24/200
# 160000/160000 [==============================] - 32s 201us/step - loss: 6.4890e-05 - val_loss: 6.6542e-05
#
# Epoch 00024: val_loss did not improve from 0.00006
# Epoch 25/200
# 160000/160000 [==============================] - 38s 239us/step - loss: 6.4126e-05 - val_loss: 5.8453e-05
#
# Epoch 00025: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 26/200
# 160000/160000 [==============================] - 32s 200us/step - loss: 6.4362e-05 - val_loss: 6.1910e-05
#
# Epoch 00026: val_loss did not improve from 0.00006
# Epoch 27/200
# 160000/160000 [==============================] - 39s 243us/step - loss: 6.3928e-05 - val_loss: 6.0792e-05
#
# Epoch 00027: val_loss did not improve from 0.00006
# Epoch 28/200
# 160000/160000 [==============================] - 37s 231us/step - loss: 6.4162e-05 - val_loss: 6.4635e-05
#
# Epoch 00028: val_loss did not improve from 0.00006
# Epoch 29/200
# 160000/160000 [==============================] - 35s 221us/step - loss: 6.4022e-05 - val_loss: 5.9957e-05
#
# Epoch 00029: val_loss did not improve from 0.00006
# Epoch 30/200
# 160000/160000 [==============================] - 33s 204us/step - loss: 6.3792e-05 - val_loss: 5.9297e-05
#
# Epoch 00030: val_loss did not improve from 0.00006
# Epoch 31/200
# 160000/160000 [==============================] - 25s 155us/step - loss: 6.3826e-05 - val_loss: 6.5347e-05
#
# Epoch 00031: val_loss did not improve from 0.00006
# Epoch 32/200
# 160000/160000 [==============================] - 38s 239us/step - loss: 6.3429e-05 - val_loss: 5.7667e-05
#
# Epoch 00032: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 33/200
# 160000/160000 [==============================] - 36s 224us/step - loss: 6.3565e-05 - val_loss: 6.2684e-05
#
# Epoch 00033: val_loss did not improve from 0.00006
# Epoch 34/200
# 160000/160000 [==============================] - 40s 251us/step - loss: 6.3253e-05 - val_loss: 6.3124e-05
#
# Epoch 00034: val_loss did not improve from 0.00006
# Epoch 35/200
# 160000/160000 [==============================] - 37s 233us/step - loss: 6.3632e-05 - val_loss: 5.9921e-05
#
# Epoch 00035: val_loss did not improve from 0.00006
# Epoch 36/200
# 160000/160000 [==============================] - 36s 227us/step - loss: 6.3077e-05 - val_loss: 5.9446e-05
#
# Epoch 00036: val_loss did not improve from 0.00006
# Epoch 37/200
# 160000/160000 [==============================] - 38s 237us/step - loss: 6.3217e-05 - val_loss: 5.6807e-05
#
# Epoch 00037: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 38/200
# 160000/160000 [==============================] - 29s 181us/step - loss: 6.3064e-05 - val_loss: 5.8199e-05
#
# Epoch 00038: val_loss did not improve from 0.00006
# Epoch 39/200
# 160000/160000 [==============================] - 35s 220us/step - loss: 6.3325e-05 - val_loss: 5.9221e-05
#
# Epoch 00039: val_loss did not improve from 0.00006
# Epoch 40/200
# 160000/160000 [==============================] - 37s 232us/step - loss: 6.2786e-05 - val_loss: 6.7776e-05
#
# Epoch 00040: val_loss did not improve from 0.00006
# Epoch 41/200
# 160000/160000 [==============================] - 29s 184us/step - loss: 6.2702e-05 - val_loss: 6.0224e-05
#
# Epoch 00041: val_loss did not improve from 0.00006
# Epoch 42/200
# 160000/160000 [==============================] - 40s 252us/step - loss: 6.2825e-05 - val_loss: 6.0896e-05
#
# Epoch 00042: val_loss did not improve from 0.00006
# Epoch 43/200
# 160000/160000 [==============================] - 36s 225us/step - loss: 6.2533e-05 - val_loss: 6.3336e-05
#
# Epoch 00043: val_loss did not improve from 0.00006
# Epoch 44/200
# 160000/160000 [==============================] - 40s 248us/step - loss: 6.2366e-05 - val_loss: 5.8711e-05
#
# Epoch 00044: val_loss did not improve from 0.00006
# Epoch 45/200
# 160000/160000 [==============================] - 29s 178us/step - loss: 6.2789e-05 - val_loss: 6.3802e-05
#
# Epoch 00045: val_loss did not improve from 0.00006
# Epoch 46/200
# 160000/160000 [==============================] - 35s 220us/step - loss: 6.2385e-05 - val_loss: 7.0346e-05
#
# Epoch 00046: val_loss did not improve from 0.00006
# Epoch 47/200
# 160000/160000 [==============================] - 35s 219us/step - loss: 6.2410e-05 - val_loss: 5.8125e-05
#
# Epoch 00047: val_loss did not improve from 0.00006
# Epoch 48/200
# 160000/160000 [==============================] - 31s 197us/step - loss: 6.2295e-05 - val_loss: 5.9771e-05
#
# Epoch 00048: val_loss did not improve from 0.00006
# Epoch 49/200
# 160000/160000 [==============================] - 28s 174us/step - loss: 6.2196e-05 - val_loss: 7.6513e-05
#
# Epoch 00049: val_loss did not improve from 0.00006
# Epoch 50/200
# 160000/160000 [==============================] - 30s 186us/step - loss: 6.2416e-05 - val_loss: 6.2296e-05
#
# Epoch 00050: val_loss did not improve from 0.00006
# Epoch 51/200
# 160000/160000 [==============================] - 31s 196us/step - loss: 6.2195e-05 - val_loss: 5.7147e-05
#
# Epoch 00051: val_loss did not improve from 0.00006
# Epoch 52/200
# 160000/160000 [==============================] - 32s 200us/step - loss: 6.2399e-05 - val_loss: 5.5616e-05
#
# Epoch 00052: val_loss improved from 0.00006 to 0.00006, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 53/200
# 160000/160000 [==============================] - 30s 185us/step - loss: 6.2258e-05 - val_loss: 5.8470e-05
#
# Epoch 00053: val_loss did not improve from 0.00006
# Epoch 54/200
# 160000/160000 [==============================] - 29s 183us/step - loss: 6.2034e-05 - val_loss: 5.7411e-05
#
# Epoch 00054: val_loss did not improve from 0.00006
# Epoch 55/200
# 160000/160000 [==============================] - 25s 155us/step - loss: 6.1692e-05 - val_loss: 6.6261e-05
#
# Epoch 00055: val_loss did not improve from 0.00006
# Epoch 56/200
# 160000/160000 [==============================] - 24s 151us/step - loss: 6.2052e-05 - val_loss: 6.1851e-05
#
# Epoch 00056: val_loss did not improve from 0.00006
# Epoch 57/200
# 160000/160000 [==============================] - 15s 96us/step - loss: 6.2010e-05 - val_loss: 6.2164e-05
#
# Epoch 00057: val_loss did not improve from 0.00006
# Epoch 58/200
# 160000/160000 [==============================] - 16s 100us/step - loss: 6.1791e-05 - val_loss: 5.8817e-05
#
# Epoch 00058: val_loss did not improve from 0.00006
# Epoch 59/200
# 160000/160000 [==============================] - 15s 96us/step - loss: 6.1490e-05 - val_loss: 6.2140e-05
#
# Epoch 00059: val_loss did not improve from 0.00006
# Epoch 60/200
# 160000/160000 [==============================] - 16s 98us/step - loss: 6.1591e-05 - val_loss: 6.6324e-05
#
# Epoch 00060: val_loss did not improve from 0.00006
# Epoch 61/200
# 160000/160000 [==============================] - 15s 96us/step - loss: 6.0578e-05 - val_loss: 6.2803e-05
#
# Epoch 00061: val_loss did not improve from 0.00006
# Epoch 62/200
# 160000/160000 [==============================] - 17s 104us/step - loss: 5.9381e-05 - val_loss: 5.9732e-05
#
# Epoch 00062: val_loss did not improve from 0.00006
# Epoch 63/200
# 160000/160000 [==============================] - 17s 103us/step - loss: 5.8720e-05 - val_loss: 5.9246e-05
#
# Epoch 00063: val_loss did not improve from 0.00006
# Epoch 64/200
# 160000/160000 [==============================] - 15s 97us/step - loss: 5.7695e-05 - val_loss: 6.7116e-05
#
# Epoch 00064: val_loss did not improve from 0.00006
# Epoch 65/200
# 160000/160000 [==============================] - 15s 97us/step - loss: 5.1408e-05 - val_loss: 4.6311e-05
#
# Epoch 00065: val_loss improved from 0.00006 to 0.00005, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 66/200
# 160000/160000 [==============================] - 16s 97us/step - loss: 4.7430e-05 - val_loss: 4.4323e-05
#
# Epoch 00066: val_loss improved from 0.00005 to 0.00004, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 67/200
# 160000/160000 [==============================] - 18s 114us/step - loss: 4.6670e-05 - val_loss: 4.1731e-05
#
# Epoch 00067: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 68/200
# 160000/160000 [==============================] - 18s 115us/step - loss: 4.6308e-05 - val_loss: 4.4443e-05
#
# Epoch 00068: val_loss did not improve from 0.00004
# Epoch 69/200
# 160000/160000 [==============================] - 15s 97us/step - loss: 4.6218e-05 - val_loss: 4.9284e-05
#
# Epoch 00069: val_loss did not improve from 0.00004
# Epoch 70/200
# 160000/160000 [==============================] - 17s 104us/step - loss: 4.5988e-05 - val_loss: 5.2383e-05
#
# Epoch 00070: val_loss did not improve from 0.00004
# Epoch 71/200
# 160000/160000 [==============================] - 19s 122us/step - loss: 4.5614e-05 - val_loss: 4.0532e-05
#
# Epoch 00071: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 72/200
# 160000/160000 [==============================] - 19s 117us/step - loss: 4.5377e-05 - val_loss: 4.9336e-05
#
# Epoch 00072: val_loss did not improve from 0.00004
# Epoch 73/200
# 160000/160000 [==============================] - 16s 100us/step - loss: 4.5577e-05 - val_loss: 4.6967e-05
#
# Epoch 00073: val_loss did not improve from 0.00004
# Epoch 74/200
# 160000/160000 [==============================] - 17s 103us/step - loss: 4.5206e-05 - val_loss: 4.6552e-05
#
# Epoch 00074: val_loss did not improve from 0.00004
# Epoch 75/200
# 160000/160000 [==============================] - 16s 100us/step - loss: 4.5146e-05 - val_loss: 4.3848e-05
#
# Epoch 00075: val_loss did not improve from 0.00004
# Epoch 76/200
# 160000/160000 [==============================] - 16s 101us/step - loss: 4.5138e-05 - val_loss: 4.1983e-05
#
# Epoch 00076: val_loss did not improve from 0.00004
# Epoch 77/200
# 160000/160000 [==============================] - 16s 101us/step - loss: 4.5299e-05 - val_loss: 4.0758e-05
#
# Epoch 00077: val_loss did not improve from 0.00004
# Epoch 78/200
# 160000/160000 [==============================] - 16s 101us/step - loss: 4.4973e-05 - val_loss: 4.8751e-05
#
# Epoch 00078: val_loss did not improve from 0.00004
# Epoch 79/200
# 160000/160000 [==============================] - 15s 94us/step - loss: 4.5128e-05 - val_loss: 4.0493e-05
#
# Epoch 00079: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 80/200
# 160000/160000 [==============================] - 16s 100us/step - loss: 4.4938e-05 - val_loss: 5.4765e-05
#
# Epoch 00080: val_loss did not improve from 0.00004
# Epoch 81/200
# 160000/160000 [==============================] - 15s 94us/step - loss: 4.4797e-05 - val_loss: 5.0567e-05
#
# Epoch 00081: val_loss did not improve from 0.00004
# Epoch 82/200
# 160000/160000 [==============================] - 16s 102us/step - loss: 4.4870e-05 - val_loss: 4.2014e-05
#
# Epoch 00082: val_loss did not improve from 0.00004
# Epoch 83/200
# 160000/160000 [==============================] - 23s 143us/step - loss: 4.4680e-05 - val_loss: 6.0701e-05
#
# Epoch 00083: val_loss did not improve from 0.00004
# Epoch 84/200
# 160000/160000 [==============================] - 37s 229us/step - loss: 4.4629e-05 - val_loss: 4.8313e-05
#
# Epoch 00084: val_loss did not improve from 0.00004
# Epoch 85/200
# 160000/160000 [==============================] - 34s 213us/step - loss: 4.4641e-05 - val_loss: 4.9837e-05
#
# Epoch 00085: val_loss did not improve from 0.00004
# Epoch 86/200
# 160000/160000 [==============================] - 31s 197us/step - loss: 4.4349e-05 - val_loss: 5.9725e-05
#
# Epoch 00086: val_loss did not improve from 0.00004
# Epoch 87/200
# 160000/160000 [==============================] - 27s 171us/step - loss: 4.4304e-05 - val_loss: 4.2773e-05
#
# Epoch 00087: val_loss did not improve from 0.00004
# Epoch 88/200
# 160000/160000 [==============================] - 21s 131us/step - loss: 4.4558e-05 - val_loss: 4.2485e-05
#
# Epoch 00088: val_loss did not improve from 0.00004
# Epoch 89/200
# 160000/160000 [==============================] - 18s 110us/step - loss: 4.4340e-05 - val_loss: 4.3714e-05
#
# Epoch 00089: val_loss did not improve from 0.00004
# Epoch 90/200
# 160000/160000 [==============================] - 23s 143us/step - loss: 4.3702e-05 - val_loss: 4.0518e-05
#
# Epoch 00090: val_loss did not improve from 0.00004
# Epoch 91/200
# 160000/160000 [==============================] - 16s 100us/step - loss: 4.2477e-05 - val_loss: 4.4955e-05
#
# Epoch 00091: val_loss did not improve from 0.00004
# Epoch 92/200
# 160000/160000 [==============================] - 14s 88us/step - loss: 4.1832e-05 - val_loss: 3.8181e-05
#
# Epoch 00092: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 93/200
# 160000/160000 [==============================] - 20s 126us/step - loss: 4.1720e-05 - val_loss: 4.3262e-05
#
# Epoch 00093: val_loss did not improve from 0.00004
# Epoch 94/200
# 160000/160000 [==============================] - 23s 147us/step - loss: 4.1101e-05 - val_loss: 3.5956e-05
#
# Epoch 00094: val_loss improved from 0.00004 to 0.00004, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 95/200
# 160000/160000 [==============================] - 19s 122us/step - loss: 4.1323e-05 - val_loss: 3.7431e-05
#
# Epoch 00095: val_loss did not improve from 0.00004
# Epoch 96/200
# 160000/160000 [==============================] - 27s 167us/step - loss: 4.1247e-05 - val_loss: 3.9795e-05
#
# Epoch 00096: val_loss did not improve from 0.00004
# Epoch 97/200
# 160000/160000 [==============================] - 19s 117us/step - loss: 4.0931e-05 - val_loss: 3.9108e-05
#
# Epoch 00097: val_loss did not improve from 0.00004
# Epoch 98/200
# 160000/160000 [==============================] - 25s 154us/step - loss: 4.1143e-05 - val_loss: 4.3773e-05
#
# Epoch 00098: val_loss did not improve from 0.00004
# Epoch 99/200
# 160000/160000 [==============================] - 40s 247us/step - loss: 4.1041e-05 - val_loss: 5.3493e-05
#
# Epoch 00099: val_loss did not improve from 0.00004
# Epoch 100/200
# 160000/160000 [==============================] - 26s 160us/step - loss: 4.0645e-05 - val_loss: 3.7222e-05
#
# Epoch 00100: val_loss did not improve from 0.00004
# Epoch 101/200
# 160000/160000 [==============================] - 29s 183us/step - loss: 4.0562e-05 - val_loss: 4.0054e-05
#
# Epoch 00101: val_loss did not improve from 0.00004
# Epoch 102/200
# 160000/160000 [==============================] - 19s 117us/step - loss: 4.0734e-05 - val_loss: 3.7571e-05
#
# Epoch 00102: val_loss did not improve from 0.00004
# Epoch 103/200
# 160000/160000 [==============================] - 20s 122us/step - loss: 4.0454e-05 - val_loss: 3.7013e-05
#
# Epoch 00103: val_loss did not improve from 0.00004
# Epoch 104/200
# 160000/160000 [==============================] - 19s 122us/step - loss: 4.0581e-05 - val_loss: 6.3522e-05
#
# Epoch 00104: val_loss did not improve from 0.00004
# Epoch 105/200
# 160000/160000 [==============================] - 19s 120us/step - loss: 4.0512e-05 - val_loss: 3.6171e-05
#
# Epoch 00105: val_loss did not improve from 0.00004
# Epoch 106/200
# 160000/160000 [==============================] - 22s 137us/step - loss: 4.0210e-05 - val_loss: 3.6913e-05
#
# Epoch 00106: val_loss did not improve from 0.00004
# Epoch 107/200
# 160000/160000 [==============================] - 21s 132us/step - loss: 4.0216e-05 - val_loss: 3.9808e-05
#
# Epoch 00107: val_loss did not improve from 0.00004
# Epoch 108/200
# 160000/160000 [==============================] - 31s 193us/step - loss: 4.0146e-05 - val_loss: 3.8765e-05
#
# Epoch 00108: val_loss did not improve from 0.00004
# Epoch 109/200
# 160000/160000 [==============================] - 27s 169us/step - loss: 3.9740e-05 - val_loss: 3.8582e-05
#
# Epoch 00109: val_loss did not improve from 0.00004
# Epoch 110/200
# 160000/160000 [==============================] - 21s 128us/step - loss: 3.9737e-05 - val_loss: 3.7082e-05
#
# Epoch 00110: val_loss did not improve from 0.00004
# Epoch 111/200
# 160000/160000 [==============================] - 30s 184us/step - loss: 3.8805e-05 - val_loss: 3.7923e-05
#
# Epoch 00111: val_loss did not improve from 0.00004
# Epoch 112/200
# 160000/160000 [==============================] - 21s 130us/step - loss: 3.8302e-05 - val_loss: 3.6302e-05
#
# Epoch 00112: val_loss did not improve from 0.00004
# Epoch 113/200
# 160000/160000 [==============================] - 20s 124us/step - loss: 3.7948e-05 - val_loss: 3.4696e-05
#
# Epoch 00113: val_loss improved from 0.00004 to 0.00003, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 114/200
# 160000/160000 [==============================] - 31s 192us/step - loss: 3.7649e-05 - val_loss: 3.5714e-05
#
# Epoch 00114: val_loss did not improve from 0.00003
# Epoch 115/200
# 160000/160000 [==============================] - 24s 152us/step - loss: 3.7686e-05 - val_loss: 3.8992e-05
#
# Epoch 00115: val_loss did not improve from 0.00003
# Epoch 116/200
# 160000/160000 [==============================] - 24s 153us/step - loss: 3.7586e-05 - val_loss: 4.7907e-05
#
# Epoch 00116: val_loss did not improve from 0.00003
# Epoch 117/200
# 160000/160000 [==============================] - 23s 146us/step - loss: 3.7579e-05 - val_loss: 3.4847e-05
#
# Epoch 00117: val_loss did not improve from 0.00003
# Epoch 118/200
# 160000/160000 [==============================] - 24s 147us/step - loss: 3.7229e-05 - val_loss: 3.3749e-05
#
# Epoch 00118: val_loss improved from 0.00003 to 0.00003, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 119/200
# 160000/160000 [==============================] - 28s 174us/step - loss: 3.7288e-05 - val_loss: 3.7590e-05
#
# Epoch 00119: val_loss did not improve from 0.00003
# Epoch 120/200
# 160000/160000 [==============================] - 33s 205us/step - loss: 3.7014e-05 - val_loss: 3.9135e-05
#
# Epoch 00120: val_loss did not improve from 0.00003
# Epoch 121/200
# 160000/160000 [==============================] - 27s 168us/step - loss: 3.7156e-05 - val_loss: 3.4811e-05
#
# Epoch 00121: val_loss did not improve from 0.00003
# Epoch 122/200
# 160000/160000 [==============================] - 22s 139us/step - loss: 3.7042e-05 - val_loss: 3.6000e-05
#
# Epoch 00122: val_loss did not improve from 0.00003
# Epoch 123/200
# 160000/160000 [==============================] - 24s 150us/step - loss: 3.6781e-05 - val_loss: 4.0262e-05
#
# Epoch 00123: val_loss did not improve from 0.00003
# Epoch 124/200
# 160000/160000 [==============================] - 21s 133us/step - loss: 3.6845e-05 - val_loss: 3.7789e-05
#
# Epoch 00124: val_loss did not improve from 0.00003
# Epoch 125/200
# 160000/160000 [==============================] - 22s 136us/step - loss: 3.6938e-05 - val_loss: 4.0589e-05
#
# Epoch 00125: val_loss did not improve from 0.00003
# Epoch 126/200
# 160000/160000 [==============================] - 23s 142us/step - loss: 3.6573e-05 - val_loss: 3.7734e-05
#
# Epoch 00126: val_loss did not improve from 0.00003
# Epoch 127/200
# 160000/160000 [==============================] - 22s 136us/step - loss: 3.6269e-05 - val_loss: 3.5613e-05
#
# Epoch 00127: val_loss did not improve from 0.00003
# Epoch 128/200
# 160000/160000 [==============================] - 25s 157us/step - loss: 3.6351e-05 - val_loss: 3.9268e-05
#
# Epoch 00128: val_loss did not improve from 0.00003
# Epoch 129/200
# 160000/160000 [==============================] - 26s 164us/step - loss: 3.6089e-05 - val_loss: 4.5219e-05
#
# Epoch 00129: val_loss did not improve from 0.00003
# Epoch 130/200
# 160000/160000 [==============================] - 22s 136us/step - loss: 3.6253e-05 - val_loss: 3.4901e-05
#
# Epoch 00130: val_loss did not improve from 0.00003
# Epoch 131/200
# 160000/160000 [==============================] - 22s 140us/step - loss: 3.6162e-05 - val_loss: 3.8578e-05
#
# Epoch 00131: val_loss did not improve from 0.00003
# Epoch 132/200
# 160000/160000 [==============================] - 26s 164us/step - loss: 3.6008e-05 - val_loss: 4.1661e-05
#
# Epoch 00132: val_loss did not improve from 0.00003
# Epoch 133/200
# 160000/160000 [==============================] - 26s 161us/step - loss: 3.6231e-05 - val_loss: 4.5206e-05
#
# Epoch 00133: val_loss did not improve from 0.00003
# Epoch 134/200
# 160000/160000 [==============================] - 21s 128us/step - loss: 3.5940e-05 - val_loss: 3.3393e-05
#
# Epoch 00134: val_loss improved from 0.00003 to 0.00003, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 135/200
# 160000/160000 [==============================] - 62s 384us/step - loss: 3.5985e-05 - val_loss: 3.4685e-05
#
# Epoch 00135: val_loss did not improve from 0.00003
# Epoch 136/200
# 160000/160000 [==============================] - 49s 304us/step - loss: 3.5870e-05 - val_loss: 3.7639e-05
#
# Epoch 00136: val_loss did not improve from 0.00003
# Epoch 137/200
# 160000/160000 [==============================] - 27s 168us/step - loss: 3.6031e-05 - val_loss: 3.5123e-05
#
# Epoch 00137: val_loss did not improve from 0.00003
# Epoch 138/200
# 160000/160000 [==============================] - 25s 157us/step - loss: 3.5810e-05 - val_loss: 3.3522e-05
#
# Epoch 00138: val_loss did not improve from 0.00003
# Epoch 139/200
# 160000/160000 [==============================] - 36s 227us/step - loss: 3.6151e-05 - val_loss: 4.0289e-05
#
# Epoch 00139: val_loss did not improve from 0.00003
# Epoch 140/200
# 160000/160000 [==============================] - 36s 228us/step - loss: 3.5880e-05 - val_loss: 3.2963e-05
#
# Epoch 00140: val_loss improved from 0.00003 to 0.00003, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 141/200
# 160000/160000 [==============================] - 32s 200us/step - loss: 3.5927e-05 - val_loss: 3.4235e-05
#
# Epoch 00141: val_loss did not improve from 0.00003
# Epoch 142/200
# 160000/160000 [==============================] - 24s 152us/step - loss: 3.5775e-05 - val_loss: 3.2465e-05
#
# Epoch 00142: val_loss improved from 0.00003 to 0.00003, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 143/200
# 160000/160000 [==============================] - 24s 152us/step - loss: 3.5927e-05 - val_loss: 4.3221e-05
#
# Epoch 00143: val_loss did not improve from 0.00003
# Epoch 144/200
# 160000/160000 [==============================] - 27s 168us/step - loss: 3.5752e-05 - val_loss: 3.5435e-05
#
# Epoch 00144: val_loss did not improve from 0.00003
# Epoch 145/200
# 160000/160000 [==============================] - 33s 208us/step - loss: 3.5770e-05 - val_loss: 3.5201e-05
#
# Epoch 00145: val_loss did not improve from 0.00003
# Epoch 146/200
# 160000/160000 [==============================] - 38s 235us/step - loss: 3.6028e-05 - val_loss: 3.8757e-05
#
# Epoch 00146: val_loss did not improve from 0.00003
# Epoch 147/200
# 160000/160000 [==============================] - 28s 174us/step - loss: 3.5969e-05 - val_loss: 4.5727e-05
#
# Epoch 00147: val_loss did not improve from 0.00003
# Epoch 148/200
# 160000/160000 [==============================] - 31s 192us/step - loss: 3.5650e-05 - val_loss: 3.4994e-05
#
# Epoch 00148: val_loss did not improve from 0.00003
# Epoch 149/200
# 160000/160000 [==============================] - 37s 229us/step - loss: 3.5651e-05 - val_loss: 3.3398e-05
#
# Epoch 00149: val_loss did not improve from 0.00003
# Epoch 150/200
# 160000/160000 [==============================] - 31s 195us/step - loss: 3.5653e-05 - val_loss: 3.2355e-05
#
# Epoch 00150: val_loss improved from 0.00003 to 0.00003, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 151/200
# 160000/160000 [==============================] - 23s 143us/step - loss: 3.5971e-05 - val_loss: 3.4990e-05
#
# Epoch 00151: val_loss did not improve from 0.00003
# Epoch 152/200
# 160000/160000 [==============================] - 33s 208us/step - loss: 3.5860e-05 - val_loss: 3.4681e-05
#
# Epoch 00152: val_loss did not improve from 0.00003
# Epoch 153/200
# 160000/160000 [==============================] - 27s 168us/step - loss: 3.5625e-05 - val_loss: 3.6462e-05
#
# Epoch 00153: val_loss did not improve from 0.00003
# Epoch 154/200
# 160000/160000 [==============================] - 28s 177us/step - loss: 3.5562e-05 - val_loss: 3.7050e-05
#
# Epoch 00154: val_loss did not improve from 0.00003
# Epoch 155/200
# 160000/160000 [==============================] - 38s 240us/step - loss: 3.5960e-05 - val_loss: 3.4842e-05
#
# Epoch 00155: val_loss did not improve from 0.00003
# Epoch 156/200
# 160000/160000 [==============================] - 35s 216us/step - loss: 3.5889e-05 - val_loss: 3.3760e-05
#
# Epoch 00156: val_loss did not improve from 0.00003
# Epoch 157/200
# 160000/160000 [==============================] - 34s 215us/step - loss: 3.5602e-05 - val_loss: 3.5845e-05
#
# Epoch 00157: val_loss did not improve from 0.00003
# Epoch 158/200
# 160000/160000 [==============================] - 32s 202us/step - loss: 3.5503e-05 - val_loss: 3.2742e-05
#
# Epoch 00158: val_loss did not improve from 0.00003
# Epoch 159/200
# 160000/160000 [==============================] - 24s 149us/step - loss: 3.5430e-05 - val_loss: 3.8426e-05
#
# Epoch 00159: val_loss did not improve from 0.00003
# Epoch 160/200
# 160000/160000 [==============================] - 24s 149us/step - loss: 3.5744e-05 - val_loss: 3.4495e-05
#
# Epoch 00160: val_loss did not improve from 0.00003
# Epoch 161/200
# 160000/160000 [==============================] - 28s 178us/step - loss: 3.5625e-05 - val_loss: 4.0514e-05
#
# Epoch 00161: val_loss did not improve from 0.00003
# Epoch 162/200
# 160000/160000 [==============================] - 29s 183us/step - loss: 3.5244e-05 - val_loss: 3.4059e-05
#
# Epoch 00162: val_loss did not improve from 0.00003
# Epoch 163/200
# 160000/160000 [==============================] - 23s 143us/step - loss: 3.5402e-05 - val_loss: 3.3599e-05
#
# Epoch 00163: val_loss did not improve from 0.00003
# Epoch 164/200
# 160000/160000 [==============================] - 20s 124us/step - loss: 3.5317e-05 - val_loss: 3.4913e-05
#
# Epoch 00164: val_loss did not improve from 0.00003
# Epoch 165/200
# 160000/160000 [==============================] - 22s 140us/step - loss: 3.5302e-05 - val_loss: 3.4045e-05
#
# Epoch 00165: val_loss did not improve from 0.00003
# Epoch 166/200
# 160000/160000 [==============================] - 25s 158us/step - loss: 3.5411e-05 - val_loss: 5.8316e-05
#
# Epoch 00166: val_loss did not improve from 0.00003
# Epoch 167/200
# 160000/160000 [==============================] - 30s 190us/step - loss: 3.5244e-05 - val_loss: 3.4912e-05
#
# Epoch 00167: val_loss did not improve from 0.00003
# Epoch 168/200
# 160000/160000 [==============================] - 33s 208us/step - loss: 3.5258e-05 - val_loss: 4.7183e-05
#
# Epoch 00168: val_loss did not improve from 0.00003
# Epoch 169/200
# 160000/160000 [==============================] - 41s 254us/step - loss: 3.5377e-05 - val_loss: 3.3373e-05
#
# Epoch 00169: val_loss did not improve from 0.00003
# Epoch 170/200
# 160000/160000 [==============================] - 34s 215us/step - loss: 3.5360e-05 - val_loss: 3.1863e-05
#
# Epoch 00170: val_loss improved from 0.00003 to 0.00003, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 171/200
# 160000/160000 [==============================] - 33s 209us/step - loss: 3.5275e-05 - val_loss: 4.9234e-05
#
# Epoch 00171: val_loss did not improve from 0.00003
# Epoch 172/200
# 160000/160000 [==============================] - 34s 213us/step - loss: 3.5344e-05 - val_loss: 3.2452e-05
#
# Epoch 00172: val_loss did not improve from 0.00003
# Epoch 173/200
# 160000/160000 [==============================] - 27s 170us/step - loss: 3.5353e-05 - val_loss: 3.3223e-05
#
# Epoch 00173: val_loss did not improve from 0.00003
# Epoch 174/200
# 160000/160000 [==============================] - 27s 169us/step - loss: 3.5344e-05 - val_loss: 4.3815e-05
#
# Epoch 00174: val_loss did not improve from 0.00003
# Epoch 175/200
# 160000/160000 [==============================] - 20s 127us/step - loss: 3.5331e-05 - val_loss: 3.3722e-05
#
# Epoch 00175: val_loss did not improve from 0.00003
# Epoch 176/200
# 160000/160000 [==============================] - 21s 134us/step - loss: 3.5359e-05 - val_loss: 3.3623e-05
#
# Epoch 00176: val_loss did not improve from 0.00003
# Epoch 177/200
# 160000/160000 [==============================] - 35s 217us/step - loss: 3.5351e-05 - val_loss: 4.2459e-05
#
# Epoch 00177: val_loss did not improve from 0.00003
# Epoch 178/200
# 160000/160000 [==============================] - 25s 156us/step - loss: 3.5266e-05 - val_loss: 3.9286e-05
#
# Epoch 00178: val_loss did not improve from 0.00003
# Epoch 179/200
# 160000/160000 [==============================] - 40s 249us/step - loss: 3.5251e-05 - val_loss: 3.4738e-05
#
# Epoch 00179: val_loss did not improve from 0.00003
# Epoch 180/200
# 160000/160000 [==============================] - 43s 267us/step - loss: 3.5201e-05 - val_loss: 3.2427e-05
#
# Epoch 00180: val_loss did not improve from 0.00003
# Epoch 181/200
# 160000/160000 [==============================] - 46s 287us/step - loss: 3.5097e-05 - val_loss: 3.2058e-05
#
# Epoch 00181: val_loss did not improve from 0.00003
# Epoch 182/200
# 160000/160000 [==============================] - 46s 286us/step - loss: 3.4959e-05 - val_loss: 3.2984e-05
#
# Epoch 00182: val_loss did not improve from 0.00003
# Epoch 183/200
# 160000/160000 [==============================] - 47s 293us/step - loss: 3.5348e-05 - val_loss: 3.7910e-05
#
# Epoch 00183: val_loss did not improve from 0.00003
# Epoch 184/200
# 160000/160000 [==============================] - 49s 308us/step - loss: 3.5162e-05 - val_loss: 3.2713e-05
#
# Epoch 00184: val_loss did not improve from 0.00003
# Epoch 185/200
# 160000/160000 [==============================] - 41s 257us/step - loss: 3.5187e-05 - val_loss: 3.4571e-05
#
# Epoch 00185: val_loss did not improve from 0.00003
# Epoch 186/200
# 160000/160000 [==============================] - 39s 245us/step - loss: 3.5041e-05 - val_loss: 3.2738e-05
#
# Epoch 00186: val_loss did not improve from 0.00003
# Epoch 187/200
# 160000/160000 [==============================] - 42s 263us/step - loss: 3.5389e-05 - val_loss: 3.3936e-05
#
# Epoch 00187: val_loss did not improve from 0.00003
# Epoch 188/200
# 160000/160000 [==============================] - 42s 263us/step - loss: 3.4985e-05 - val_loss: 3.4269e-05
#
# Epoch 00188: val_loss did not improve from 0.00003
# Epoch 189/200
# 160000/160000 [==============================] - 38s 240us/step - loss: 3.5086e-05 - val_loss: 3.7990e-05
#
# Epoch 00189: val_loss did not improve from 0.00003
# Epoch 190/200
# 160000/160000 [==============================] - 46s 288us/step - loss: 3.5080e-05 - val_loss: 3.7098e-05
#
# Epoch 00190: val_loss did not improve from 0.00003
# Epoch 191/200
# 160000/160000 [==============================] - 40s 252us/step - loss: 3.5165e-05 - val_loss: 3.3145e-05
#
# Epoch 00191: val_loss did not improve from 0.00003
# Epoch 192/200
# 160000/160000 [==============================] - 37s 232us/step - loss: 3.4998e-05 - val_loss: 3.9249e-05
#
# Epoch 00192: val_loss did not improve from 0.00003
# Epoch 193/200
# 160000/160000 [==============================] - 31s 194us/step - loss: 3.5076e-05 - val_loss: 3.8834e-05
#
# Epoch 00193: val_loss did not improve from 0.00003
# Epoch 194/200
# 160000/160000 [==============================] - 41s 254us/step - loss: 3.5003e-05 - val_loss: 3.5854e-05
#
# Epoch 00194: val_loss did not improve from 0.00003
# Epoch 195/200
# 160000/160000 [==============================] - 40s 250us/step - loss: 3.5032e-05 - val_loss: 4.2025e-05
#
# Epoch 00195: val_loss did not improve from 0.00003
# Epoch 196/200
# 160000/160000 [==============================] - 36s 224us/step - loss: 3.5083e-05 - val_loss: 3.2606e-05
#
# Epoch 00196: val_loss did not improve from 0.00003
# Epoch 197/200
# 160000/160000 [==============================] - 27s 167us/step - loss: 3.4929e-05 - val_loss: 4.1334e-05
#
# Epoch 00197: val_loss did not improve from 0.00003
# Epoch 198/200
# 160000/160000 [==============================] - 24s 149us/step - loss: 3.4912e-05 - val_loss: 3.3620e-05
#
# Epoch 00198: val_loss did not improve from 0.00003
# Epoch 199/200
# 160000/160000 [==============================] - 23s 146us/step - loss: 3.4905e-05 - val_loss: 3.1856e-05
#
# Epoch 00199: val_loss improved from 0.00003 to 0.00003, saving model to NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5weights.hdf5
# Epoch 200/200
# 160000/160000 [==============================] - 24s 150us/step - loss: 3.4883e-05 - val_loss: 3.2472e-05
#
# Epoch 00200: val_loss did not improve from 0.00003

# %%
nn5_scint_decays=np.linspace(15,50,10)
nn5_ratios=np.linspace(-25,25,10)
nn5_eventsperexperiment=500
nn5_results, nn5_actual_values, nn5_labels=model_verifier('FinerParameterSpace500events1000photons300binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %% [markdown]
# # 10,000 photon model on 5,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('FinerParameterSpace500events5000photons300binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %% [markdown]
# # 10,000 photon model on 1,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('FinerParameterSpace500events1000photons300binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %% [markdown]
# # 10,000 photon model on 2,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('FinerParameterSpace500events2000photons300binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %% [markdown]
# # 10,000 photon model on 3,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('FinerParameterSpace500events3000photons300binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %% [markdown]
# # 10,000 photon model on 4,000

# %%
nn5_results, nn5_actual_values, nn5_labels=model_verifier('FinerParameterSpace500events4000photons300binsTestingLibrary.hdf5','NarrowerParameterSpace500events10000photons300binsModel_20x20_normalized_max.hdf5', nn5_ratios,nn5_scint_decays,nn5_eventsperexperiment)

# %%
nn5_profile=2*(nn5_results-nn5_actual_values)/(nn5_results+nn5_actual_values)
nn5_sum_to_one=[]
nn5_profile=np.asarray(nn5_profile)
nn5_profile_labels=[]
nn5_profile_cerenkov_mean=[]
nn5_profile_scintillation_mean=[]
nn5_profile_cerenkov_stdev=[]
nn5_profile_scintillation_stdev=[]
for i in range(len(nn5_profile)):
    #print(len([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_mean.append(np.mean([item[0] for item in nn5_profile[i]]))
    nn5_profile_cerenkov_stdev.append(np.std([item[0] for item in nn5_profile[i]]))
    nn5_profile_scintillation_mean.append(np.mean([item[1] for item in nn5_profile[i]]))
    nn5_profile_scintillation_stdev.append(np.std([item[1] for item in nn5_profile[i]]))
    nn5_profile_labels.append(nn5_labels[i][0])
    nn5_sum_to_one.append(np.mean([item[0]+item[1] for item in nn5_results[i]]))

nn5_profile_labels_clean=[]
for label in nn5_profile_labels:
    index=label.find('/',2)
    #print(label[1:index])
    nn5_profile_labels_clean.append(label[1:index])

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean)
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev)
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean)
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev)
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean)
nn5_sum_to_one=np.asarray(nn5_sum_to_one)

nn5_profile_cerenkov_mean=np.asarray(nn5_profile_cerenkov_mean.reshape(10,10))
nn5_profile_cerenkov_stdev=np.asarray(nn5_profile_cerenkov_stdev.reshape(10,10))
nn5_profile_scintillation_mean=np.asarray(nn5_profile_scintillation_mean.reshape(10,10))
nn5_profile_scintillation_stdev=np.asarray(nn5_profile_scintillation_stdev.reshape(10,10))
nn5_profile_labels_clean=np.asarray(nn5_profile_labels_clean.reshape(10,10))
nn5_sum_to_one=np.asarray(nn5_sum_to_one.reshape(10,10))


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_cerenkov_mean), levels=[0, 0.05])
plt.title("Area of Validity for Cerenkov Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, abs(nn5_profile_scintillation_mean), levels=[0, 0.05])
plt.title("Area of Validity for Scintillation Prediction (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


nn5_max_error=[]
for cerenkov_vector, scintillation_vector in zip(nn5_profile_cerenkov_mean, nn5_profile_scintillation_mean):
    temp=[]
    for cerenkov_val, scintillation_val in zip(cerenkov_vector, scintillation_vector):
        temp.append(max(abs(cerenkov_val),abs(scintillation_val)))
    nn5_max_error.append(temp)

plt.figure()
plot=plt.contourf(nn5_scint_decays, nn5_ratios, nn5_max_error , levels=[0, 0.05])
plt.title("Area of Validity for Prediction of Both (Absolute Percent Difference of less than 5%)")
plt.xlabel("scintillation decay (ns)")
plt.ylabel("C/S ratio")
plt.colorbar()


plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_scintillation_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_scintillation_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Scintillation Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
#plt.clim(-1,1)
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

plt.figure()
fig, ax = plt.subplots()
ax.set_yticks(np.arange(len(nn5_ratios)))
ax.set_xticks(np.arange(len(nn5_scint_decays)))
ax.set_yticklabels(np.round(nn5_ratios,2))
ax.set_xticklabels(np.round(nn5_scint_decays,2))
im = ax.imshow(abs(nn5_profile_cerenkov_mean))#  extent=(15, 50, 25, -25))
for i in range(len(nn5_ratios)):
    for j in range(len(nn5_scint_decays)):
        text = plt.text(j, i, abs(round(nn5_profile_cerenkov_mean[i, j],3)),
                       ha="center", va="center", color="black", fontsize=10)
plt.colorbar(im)
plt.title("Mean of Absolute Percent Differences for Cerenkov Radiation")
plt.xlabel("Scintillation Decay Constant (ns)")
plt.ylabel("Photostatistics Ratio (C/S)")
fig.tight_layout()
fig.set_size_inches(10,10)
plt.gca().invert_yaxis()
for im in plt.gca().get_images():
    im.set_clim(vmin=0, vmax=0.05)

# %%
pulse=Pulse(1000,10,25)

# %%
a,b,c,d=pulse.output()

# %%
vals=[]

for i in range(len(d)-1):
    vals.append((d[i]+d[i+1])/2)

# %%
print(len(np.linspace(0,250,100)))

# %%
print(vals)
